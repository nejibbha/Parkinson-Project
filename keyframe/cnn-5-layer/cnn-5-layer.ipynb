# %%
import timm
import torch
import torch.nn as nn
import copy
from torch.utils.data import DataLoader, random_split
from sklearn.metrics import confusion_matrix
from torchvision import transforms, datasets
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
class CNN_5Layer(nn.Module):
    def __init__(self):
        super(CNN_5Layer, self).__init__()

        self.conv_layers = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),
        )

        dummy_input = torch.randn(1, 3, 224, 224)
        conv_output_size = self._get_conv_output_size(dummy_input)

        self.fc_layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(conv_output_size, 4, bias=True),
            nn.Softmax(dim=1)
        )

        self.l1_regularizer = nn.L1Loss()

    def _get_conv_output_size(self, x):
        with torch.no_grad():
            conv_output = self.conv_layers(x)
        return conv_output.view(x.size(0), -1).shape[1]

    def forward(self, x):
        x = self.conv_layers(x)
        x = self.fc_layers(x)
        return x

# %%
class CNN_6Layer(nn.Module):
    def __init__(self):
        super(CNN_6Layer, self).__init__()

        self.conv_layers = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),
        )

        dummy_input = torch.randn(1, 3, 224, 224)
        conv_output_size = self._get_conv_output_size(dummy_input)

        self.fc_layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(conv_output_size, 4, bias=True),
            nn.Softmax(dim=1)
        )

        self.l1_regularizer = nn.L1Loss()

    def _get_conv_output_size(self, x):
        with torch.no_grad():
            conv_output = self.conv_layers(x)
        return conv_output.view(x.size(0), -1).shape[1]

    def forward(self, x):
        x = self.conv_layers(x)
        x = self.fc_layers(x)
        return x

# %%
def create_cnn(model_name):
    if model_name == '5-layer': model = CNN_5Layer()
    if model_name == '6-layer': model = CNN_6Layer()

    return model

# %%
transform = transforms.Compose([transforms.Resize((224, 224)), transforms.ToTensor(), transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])])

dataset = datasets.ImageFolder(root='/home/ubuntu/Parkinson-Project/keyframes/energy_images', transform=transform)

total_size = len(dataset)
train_size = int(total_size * 0.8) 
validation_size = int(total_size * 0.1) 
test_size = total_size - train_size - validation_size
generator = torch.Generator().manual_seed(0) 
train_dataset, validation_dataset, test_dataset = random_split(dataset, [train_size, validation_size, test_size], generator=generator)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(validation_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
experiment = 'cnn-5-layer-130-epochs-early-stopping-with-regularization-keyframes'

# %%
model_type = '5-layer'
model = create_cnn(model_type)

# Model summary to check architecture
print(model)
# Out:
# CNN_5Layer(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.5, inplace=False)
#     (5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Dropout(p=0.5, inplace=False)
#     (10): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Dropout(p=0.5, inplace=False)
#     (15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Dropout(p=0.5, inplace=False)
#   )
#   (fc_layers): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=12544, out_features=4, bias=True)
#     (2): Softmax(dim=1)
#   )
#   (l1_regularizer): L1Loss()
# )

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model.to(device)

num_epochs = 130  
patience = 20  
best_val_loss = float('inf')  
best_model = None  

train_loss_list = list()
val_loss_list = list()
train_accuracy_list = list()
val_accuracy_list = list()

for epoch in range(num_epochs):
    model.train() 
    running_loss = 0.0
    correct = 0
    total = 0
    print(f"Epoch {epoch+1}")

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)  

        optimizer.zero_grad()  
        outputs = model(images)  
        loss = criterion(outputs, labels)  
        loss.backward() 
        optimizer.step() 

        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        print(f"Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * correct / total:.2f}%")

    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct / total
    print(f"Training - Epoch {epoch+1}, Loss: {train_loss:.6f}, Accuracy: {train_accuracy:.2f}%")

    train_loss_list.append(train_loss)
    train_accuracy_list.append(train_accuracy)

    # Validation step
    model.eval()  
    val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():  
        for batch_idx, (images, labels) in enumerate(val_loader):
            images, labels = images.to(device), labels.to(device)  

            outputs = model(images) 
            loss = criterion(outputs, labels) 

            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

            print(f"Validation Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * val_correct / val_total:.2f}%")

    val_loss /= len(val_loader)
    val_accuracy = 100 * val_correct / val_total
    print(f"Validation - Epoch {epoch+1}, Loss: {val_loss:.6f}, Accuracy: {val_accuracy:.2f}%")

    val_loss_list.append(val_loss)
    val_accuracy_list.append(val_accuracy)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = copy.deepcopy(model)
        patience_counter = 0
    else:
        patience_counter += 1

    print(f'Patience—{patience_counter}')

    # Check for early stopping
    if patience_counter >= patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

model = best_model
torch.save(model.state_dict(), f'{experiment}-{model_type}')
# Out:
# Using device: cuda:0
# Epoch 1
# Batch 1, Loss: 1.452714, Accuracy: 20.31%
# Batch 2, Loss: 1.409879, Accuracy: 23.44%
# Batch 3, Loss: 1.387769, Accuracy: 25.00%
# Batch 4, Loss: 1.377563, Accuracy: 26.17%
# Batch 5, Loss: 1.414204, Accuracy: 25.62%
# Batch 6, Loss: 1.381661, Accuracy: 27.08%
# Batch 7, Loss: 1.420054, Accuracy: 26.83%
# Training - Epoch 1, Loss: 1.406263, Accuracy: 26.83%
# Validation Batch 1, Loss: 1.364295, Accuracy: 52.94%
# Validation - Epoch 1, Loss: 1.364295, Accuracy: 52.94%
# Patience—0
# Epoch 2
# Batch 1, Loss: 1.364259, Accuracy: 28.12%
# Batch 2, Loss: 1.376019, Accuracy: 28.91%
# Batch 3, Loss: 1.364192, Accuracy: 28.12%
# Batch 4, Loss: 1.371592, Accuracy: 28.12%
# Batch 5, Loss: 1.419467, Accuracy: 27.81%
# Batch 6, Loss: 1.409954, Accuracy: 27.08%
# Batch 7, Loss: 1.373134, Accuracy: 27.56%
# Training - Epoch 2, Loss: 1.382659, Accuracy: 27.56%
# Validation Batch 1, Loss: 1.345227, Accuracy: 52.94%
# Validation - Epoch 2, Loss: 1.345227, Accuracy: 52.94%
# Patience—0
# Epoch 3
# Batch 1, Loss: 1.303863, Accuracy: 45.31%
# Batch 2, Loss: 1.372377, Accuracy: 35.94%
# Batch 3, Loss: 1.413232, Accuracy: 32.81%
# Batch 4, Loss: 1.303741, Accuracy: 34.77%
# Batch 5, Loss: 1.276788, Accuracy: 36.56%
# Batch 6, Loss: 1.411911, Accuracy: 34.90%
# Batch 7, Loss: 1.282585, Accuracy: 35.37%
# Training - Epoch 3, Loss: 1.337785, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.335519, Accuracy: 52.94%
# Validation - Epoch 3, Loss: 1.335519, Accuracy: 52.94%
# Patience—0
# Epoch 4
# Batch 1, Loss: 1.314990, Accuracy: 37.50%
# Batch 2, Loss: 1.327660, Accuracy: 36.72%
# Batch 3, Loss: 1.364869, Accuracy: 36.98%
# Batch 4, Loss: 1.350467, Accuracy: 36.72%
# Batch 5, Loss: 1.325879, Accuracy: 36.56%
# Batch 6, Loss: 1.374134, Accuracy: 35.68%
# Batch 7, Loss: 1.270631, Accuracy: 36.10%
# Training - Epoch 4, Loss: 1.332661, Accuracy: 36.10%
# Validation Batch 1, Loss: 1.336684, Accuracy: 47.06%
# Validation - Epoch 4, Loss: 1.336684, Accuracy: 47.06%
# Patience—1
# Epoch 5
# Batch 1, Loss: 1.233552, Accuracy: 50.00%
# Batch 2, Loss: 1.343036, Accuracy: 43.75%
# Batch 3, Loss: 1.336904, Accuracy: 40.10%
# Batch 4, Loss: 1.313841, Accuracy: 40.23%
# Batch 5, Loss: 1.311414, Accuracy: 40.00%
# Batch 6, Loss: 1.276345, Accuracy: 40.62%
# Batch 7, Loss: 1.355147, Accuracy: 40.00%
# Training - Epoch 5, Loss: 1.310034, Accuracy: 40.00%
# Validation Batch 1, Loss: 1.342000, Accuracy: 27.45%
# Validation - Epoch 5, Loss: 1.342000, Accuracy: 27.45%
# Patience—2
# Epoch 6
# Batch 1, Loss: 1.298865, Accuracy: 37.50%
# Batch 2, Loss: 1.328447, Accuracy: 34.38%
# Batch 3, Loss: 1.300576, Accuracy: 36.46%
# Batch 4, Loss: 1.314162, Accuracy: 36.33%
# Batch 5, Loss: 1.379942, Accuracy: 35.94%
# Batch 6, Loss: 1.302513, Accuracy: 37.50%
# Batch 7, Loss: 1.279443, Accuracy: 37.56%
# Training - Epoch 6, Loss: 1.314850, Accuracy: 37.56%
# Validation Batch 1, Loss: 1.347574, Accuracy: 27.45%
# Validation - Epoch 6, Loss: 1.347574, Accuracy: 27.45%
# Patience—3
# Epoch 7
# Batch 1, Loss: 1.318208, Accuracy: 35.94%
# Batch 2, Loss: 1.295824, Accuracy: 38.28%
# Batch 3, Loss: 1.352856, Accuracy: 38.02%
# Batch 4, Loss: 1.277241, Accuracy: 39.84%
# Batch 5, Loss: 1.322106, Accuracy: 39.38%
# Batch 6, Loss: 1.314860, Accuracy: 39.32%
# Batch 7, Loss: 1.262128, Accuracy: 39.76%
# Training - Epoch 7, Loss: 1.306175, Accuracy: 39.76%
# Validation Batch 1, Loss: 1.343355, Accuracy: 27.45%
# Validation - Epoch 7, Loss: 1.343355, Accuracy: 27.45%
# Patience—4
# Epoch 8
# Batch 1, Loss: 1.266043, Accuracy: 43.75%
# Batch 2, Loss: 1.330979, Accuracy: 39.84%
# Batch 3, Loss: 1.319832, Accuracy: 38.02%
# Batch 4, Loss: 1.316119, Accuracy: 38.67%
# Batch 5, Loss: 1.315041, Accuracy: 38.44%
# Batch 6, Loss: 1.331378, Accuracy: 39.06%
# Batch 7, Loss: 1.218456, Accuracy: 39.76%
# Training - Epoch 8, Loss: 1.299693, Accuracy: 39.76%
# Validation Batch 1, Loss: 1.332621, Accuracy: 31.37%
# Validation - Epoch 8, Loss: 1.332621, Accuracy: 31.37%
# Patience—0
# Epoch 9
# Batch 1, Loss: 1.280973, Accuracy: 45.31%
# Batch 2, Loss: 1.291694, Accuracy: 42.97%
# Batch 3, Loss: 1.302619, Accuracy: 42.19%
# Batch 4, Loss: 1.340128, Accuracy: 40.23%
# Batch 5, Loss: 1.287137, Accuracy: 40.00%
# Batch 6, Loss: 1.275063, Accuracy: 40.10%
# Batch 7, Loss: 1.306067, Accuracy: 40.00%
# Training - Epoch 9, Loss: 1.297669, Accuracy: 40.00%
# Validation Batch 1, Loss: 1.324632, Accuracy: 35.29%
# Validation - Epoch 9, Loss: 1.324632, Accuracy: 35.29%
# Patience—0
# Epoch 10
# Batch 1, Loss: 1.309576, Accuracy: 45.31%
# Batch 2, Loss: 1.269441, Accuracy: 44.53%
# Batch 3, Loss: 1.322310, Accuracy: 40.10%
# Batch 4, Loss: 1.270047, Accuracy: 41.41%
# Batch 5, Loss: 1.326132, Accuracy: 40.62%
# Batch 6, Loss: 1.209699, Accuracy: 43.23%
# Batch 7, Loss: 1.311241, Accuracy: 42.68%
# Training - Epoch 10, Loss: 1.288349, Accuracy: 42.68%
# Validation Batch 1, Loss: 1.326807, Accuracy: 35.29%
# Validation - Epoch 10, Loss: 1.326807, Accuracy: 35.29%
# Patience—1
# Epoch 11
# Batch 1, Loss: 1.292366, Accuracy: 42.19%
# Batch 2, Loss: 1.332458, Accuracy: 40.62%
# Batch 3, Loss: 1.237253, Accuracy: 44.79%
# Batch 4, Loss: 1.261767, Accuracy: 45.31%
# Batch 5, Loss: 1.254900, Accuracy: 45.94%
# Batch 6, Loss: 1.279676, Accuracy: 46.09%
# Batch 7, Loss: 1.243872, Accuracy: 46.34%
# Training - Epoch 11, Loss: 1.271756, Accuracy: 46.34%
# Validation Batch 1, Loss: 1.323503, Accuracy: 35.29%
# Validation - Epoch 11, Loss: 1.323503, Accuracy: 35.29%
# Patience—0
# Epoch 12
# Batch 1, Loss: 1.252396, Accuracy: 48.44%
# Batch 2, Loss: 1.341406, Accuracy: 39.84%
# Batch 3, Loss: 1.272867, Accuracy: 42.19%
# Batch 4, Loss: 1.220896, Accuracy: 43.75%
# Batch 5, Loss: 1.311988, Accuracy: 41.88%
# Batch 6, Loss: 1.264925, Accuracy: 41.93%
# Batch 7, Loss: 1.326007, Accuracy: 41.22%
# Training - Epoch 12, Loss: 1.284355, Accuracy: 41.22%
# Validation Batch 1, Loss: 1.324327, Accuracy: 35.29%
# Validation - Epoch 12, Loss: 1.324327, Accuracy: 35.29%
# Patience—1
# Epoch 13
# Batch 1, Loss: 1.321035, Accuracy: 34.38%
# Batch 2, Loss: 1.292706, Accuracy: 35.94%
# Batch 3, Loss: 1.259989, Accuracy: 40.10%
# Batch 4, Loss: 1.328862, Accuracy: 38.67%
# Batch 5, Loss: 1.294985, Accuracy: 39.06%
# Batch 6, Loss: 1.273197, Accuracy: 40.10%
# Batch 7, Loss: 1.288781, Accuracy: 40.00%
# Training - Epoch 13, Loss: 1.294222, Accuracy: 40.00%
# Validation Batch 1, Loss: 1.329701, Accuracy: 29.41%
# Validation - Epoch 13, Loss: 1.329701, Accuracy: 29.41%
# Patience—2
# Epoch 14
# Batch 1, Loss: 1.278286, Accuracy: 37.50%
# Batch 2, Loss: 1.254907, Accuracy: 41.41%
# Batch 3, Loss: 1.304162, Accuracy: 39.06%
# Batch 4, Loss: 1.252502, Accuracy: 41.02%
# Batch 5, Loss: 1.235762, Accuracy: 42.50%
# Batch 6, Loss: 1.269797, Accuracy: 42.71%
# Batch 7, Loss: 1.265747, Accuracy: 43.17%
# Training - Epoch 14, Loss: 1.265880, Accuracy: 43.17%
# Validation Batch 1, Loss: 1.328982, Accuracy: 33.33%
# Validation - Epoch 14, Loss: 1.328982, Accuracy: 33.33%
# Patience—3
# Epoch 15
# Batch 1, Loss: 1.282637, Accuracy: 37.50%
# Batch 2, Loss: 1.288910, Accuracy: 41.41%
# Batch 3, Loss: 1.262355, Accuracy: 41.67%
# Batch 4, Loss: 1.289623, Accuracy: 42.19%
# Batch 5, Loss: 1.294913, Accuracy: 40.62%
# Batch 6, Loss: 1.319806, Accuracy: 39.58%
# Batch 7, Loss: 1.248376, Accuracy: 40.00%
# Training - Epoch 15, Loss: 1.283803, Accuracy: 40.00%
# Validation Batch 1, Loss: 1.331204, Accuracy: 31.37%
# Validation - Epoch 15, Loss: 1.331204, Accuracy: 31.37%
# Patience—4
# Epoch 16
# Batch 1, Loss: 1.217217, Accuracy: 51.56%
# Batch 2, Loss: 1.338459, Accuracy: 44.53%
# Batch 3, Loss: 1.285269, Accuracy: 44.27%
# Batch 4, Loss: 1.221512, Accuracy: 44.53%
# Batch 5, Loss: 1.313600, Accuracy: 44.06%
# Batch 6, Loss: 1.306860, Accuracy: 43.23%
# Batch 7, Loss: 1.308773, Accuracy: 42.68%
# Training - Epoch 16, Loss: 1.284527, Accuracy: 42.68%
# Validation Batch 1, Loss: 1.332083, Accuracy: 33.33%
# Validation - Epoch 16, Loss: 1.332083, Accuracy: 33.33%
# Patience—5
# Epoch 17
# Batch 1, Loss: 1.298095, Accuracy: 45.31%
# Batch 2, Loss: 1.250837, Accuracy: 46.88%
# Batch 3, Loss: 1.289089, Accuracy: 43.23%
# Batch 4, Loss: 1.246470, Accuracy: 44.53%
# Batch 5, Loss: 1.291272, Accuracy: 44.06%
# Batch 6, Loss: 1.313520, Accuracy: 42.97%
# Batch 7, Loss: 1.335802, Accuracy: 42.44%
# Training - Epoch 17, Loss: 1.289298, Accuracy: 42.44%
# Validation Batch 1, Loss: 1.332817, Accuracy: 33.33%
# Validation - Epoch 17, Loss: 1.332817, Accuracy: 33.33%
# Patience—6
# Epoch 18
# Batch 1, Loss: 1.278397, Accuracy: 46.88%
# Batch 2, Loss: 1.299672, Accuracy: 45.31%
# Batch 3, Loss: 1.313507, Accuracy: 41.15%
# Batch 4, Loss: 1.269180, Accuracy: 41.02%
# Batch 5, Loss: 1.315655, Accuracy: 40.00%
# Batch 6, Loss: 1.273856, Accuracy: 40.36%
# Batch 7, Loss: 1.290185, Accuracy: 40.49%
# Training - Epoch 18, Loss: 1.291493, Accuracy: 40.49%
# Validation Batch 1, Loss: 1.330904, Accuracy: 33.33%
# Validation - Epoch 18, Loss: 1.330904, Accuracy: 33.33%
# Patience—7
# Epoch 19
# Batch 1, Loss: 1.294891, Accuracy: 43.75%
# Batch 2, Loss: 1.316868, Accuracy: 39.06%
# Batch 3, Loss: 1.299992, Accuracy: 38.02%
# Batch 4, Loss: 1.253733, Accuracy: 40.23%
# Batch 5, Loss: 1.278168, Accuracy: 40.62%
# Batch 6, Loss: 1.247734, Accuracy: 41.41%
# Batch 7, Loss: 1.233876, Accuracy: 41.46%
# Training - Epoch 19, Loss: 1.275037, Accuracy: 41.46%
# Validation Batch 1, Loss: 1.329086, Accuracy: 33.33%
# Validation - Epoch 19, Loss: 1.329086, Accuracy: 33.33%
# Patience—8
# Epoch 20
# Batch 1, Loss: 1.292824, Accuracy: 39.06%
# Batch 2, Loss: 1.316231, Accuracy: 38.28%
# Batch 3, Loss: 1.275246, Accuracy: 40.10%
# Batch 4, Loss: 1.241180, Accuracy: 41.80%
# Batch 5, Loss: 1.285702, Accuracy: 41.88%
# Batch 6, Loss: 1.243361, Accuracy: 43.49%
# Batch 7, Loss: 1.290846, Accuracy: 43.17%
# Training - Epoch 20, Loss: 1.277913, Accuracy: 43.17%
# Validation Batch 1, Loss: 1.335353, Accuracy: 31.37%
# Validation - Epoch 20, Loss: 1.335353, Accuracy: 31.37%
# Patience—9
# Epoch 21
# Batch 1, Loss: 1.316013, Accuracy: 40.62%
# Batch 2, Loss: 1.232688, Accuracy: 45.31%
# Batch 3, Loss: 1.292529, Accuracy: 43.75%
# Batch 4, Loss: 1.254584, Accuracy: 46.09%
# Batch 5, Loss: 1.284064, Accuracy: 44.69%
# Batch 6, Loss: 1.195433, Accuracy: 46.09%
# Batch 7, Loss: 1.218733, Accuracy: 46.59%
# Training - Epoch 21, Loss: 1.256292, Accuracy: 46.59%
# Validation Batch 1, Loss: 1.338499, Accuracy: 31.37%
# Validation - Epoch 21, Loss: 1.338499, Accuracy: 31.37%
# Patience—10
# Epoch 22
# Batch 1, Loss: 1.284138, Accuracy: 43.75%
# Batch 2, Loss: 1.269815, Accuracy: 43.75%
# Batch 3, Loss: 1.342456, Accuracy: 41.67%
# Batch 4, Loss: 1.255887, Accuracy: 41.41%
# Batch 5, Loss: 1.247144, Accuracy: 42.50%
# Batch 6, Loss: 1.324093, Accuracy: 40.62%
# Batch 7, Loss: 1.201157, Accuracy: 41.46%
# Training - Epoch 22, Loss: 1.274956, Accuracy: 41.46%
# Validation Batch 1, Loss: 1.341694, Accuracy: 31.37%
# Validation - Epoch 22, Loss: 1.341694, Accuracy: 31.37%
# Patience—11
# Epoch 23
# Batch 1, Loss: 1.326242, Accuracy: 37.50%
# Batch 2, Loss: 1.291654, Accuracy: 39.06%
# Batch 3, Loss: 1.205124, Accuracy: 43.23%
# Batch 4, Loss: 1.253110, Accuracy: 44.14%
# Batch 5, Loss: 1.242169, Accuracy: 44.38%
# Batch 6, Loss: 1.284859, Accuracy: 44.01%
# Batch 7, Loss: 1.210881, Accuracy: 44.88%
# Training - Epoch 23, Loss: 1.259149, Accuracy: 44.88%
# Validation Batch 1, Loss: 1.338374, Accuracy: 31.37%
# Validation - Epoch 23, Loss: 1.338374, Accuracy: 31.37%
# Patience—12
# Epoch 24
# Batch 1, Loss: 1.261309, Accuracy: 43.75%
# Batch 2, Loss: 1.221247, Accuracy: 46.88%
# Batch 3, Loss: 1.254965, Accuracy: 44.27%
# Batch 4, Loss: 1.260773, Accuracy: 43.36%
# Batch 5, Loss: 1.323171, Accuracy: 41.88%
# Batch 6, Loss: 1.262494, Accuracy: 42.97%
# Batch 7, Loss: 1.218097, Accuracy: 43.66%
# Training - Epoch 24, Loss: 1.257437, Accuracy: 43.66%
# Validation Batch 1, Loss: 1.335887, Accuracy: 31.37%
# Validation - Epoch 24, Loss: 1.335887, Accuracy: 31.37%
# Patience—13
# Epoch 25
# Batch 1, Loss: 1.255817, Accuracy: 46.88%
# Batch 2, Loss: 1.240077, Accuracy: 47.66%
# Batch 3, Loss: 1.294999, Accuracy: 45.31%
# Batch 4, Loss: 1.302898, Accuracy: 43.36%
# Batch 5, Loss: 1.326761, Accuracy: 40.94%
# Batch 6, Loss: 1.242033, Accuracy: 41.93%
# Batch 7, Loss: 1.320477, Accuracy: 41.46%
# Training - Epoch 25, Loss: 1.283295, Accuracy: 41.46%
# Validation Batch 1, Loss: 1.339805, Accuracy: 29.41%
# Validation - Epoch 25, Loss: 1.339805, Accuracy: 29.41%
# Patience—14
# Epoch 26
# Batch 1, Loss: 1.261395, Accuracy: 43.75%
# Batch 2, Loss: 1.206439, Accuracy: 48.44%
# Batch 3, Loss: 1.298994, Accuracy: 47.40%
# Batch 4, Loss: 1.229054, Accuracy: 48.05%
# Batch 5, Loss: 1.286146, Accuracy: 46.25%
# Batch 6, Loss: 1.271982, Accuracy: 45.83%
# Batch 7, Loss: 1.340679, Accuracy: 45.12%
# Training - Epoch 26, Loss: 1.270670, Accuracy: 45.12%
# Validation Batch 1, Loss: 1.343639, Accuracy: 29.41%
# Validation - Epoch 26, Loss: 1.343639, Accuracy: 29.41%
# Patience—15
# Epoch 27
# Batch 1, Loss: 1.289622, Accuracy: 45.31%
# Batch 2, Loss: 1.324721, Accuracy: 42.97%
# Batch 3, Loss: 1.268089, Accuracy: 43.75%
# Batch 4, Loss: 1.218083, Accuracy: 44.14%
# Batch 5, Loss: 1.266956, Accuracy: 44.06%
# Batch 6, Loss: 1.257868, Accuracy: 43.23%
# Batch 7, Loss: 1.369324, Accuracy: 41.95%
# Training - Epoch 27, Loss: 1.284952, Accuracy: 41.95%
# Validation Batch 1, Loss: 1.344714, Accuracy: 31.37%
# Validation - Epoch 27, Loss: 1.344714, Accuracy: 31.37%
# Patience—16
# Epoch 28
# Batch 1, Loss: 1.249537, Accuracy: 50.00%
# Batch 2, Loss: 1.281199, Accuracy: 45.31%
# Batch 3, Loss: 1.273035, Accuracy: 44.27%
# Batch 4, Loss: 1.298877, Accuracy: 42.19%
# Batch 5, Loss: 1.222582, Accuracy: 43.75%
# Batch 6, Loss: 1.272664, Accuracy: 43.49%
# Batch 7, Loss: 1.287644, Accuracy: 43.90%
# Training - Epoch 28, Loss: 1.269363, Accuracy: 43.90%
# Validation Batch 1, Loss: 1.343433, Accuracy: 31.37%
# Validation - Epoch 28, Loss: 1.343433, Accuracy: 31.37%
# Patience—17
# Epoch 29
# Batch 1, Loss: 1.214282, Accuracy: 50.00%
# Batch 2, Loss: 1.276573, Accuracy: 46.88%
# Batch 3, Loss: 1.228140, Accuracy: 47.92%
# Batch 4, Loss: 1.233978, Accuracy: 48.83%
# Batch 5, Loss: 1.312785, Accuracy: 45.94%
# Batch 6, Loss: 1.294681, Accuracy: 45.31%
# Batch 7, Loss: 1.297949, Accuracy: 44.88%
# Training - Epoch 29, Loss: 1.265484, Accuracy: 44.88%
# Validation Batch 1, Loss: 1.341099, Accuracy: 31.37%
# Validation - Epoch 29, Loss: 1.341099, Accuracy: 31.37%
# Patience—18
# Epoch 30
# Batch 1, Loss: 1.241003, Accuracy: 48.44%
# Batch 2, Loss: 1.335119, Accuracy: 39.84%
# Batch 3, Loss: 1.286383, Accuracy: 39.58%
# Batch 4, Loss: 1.216906, Accuracy: 42.19%
# Batch 5, Loss: 1.324799, Accuracy: 40.94%
# Batch 6, Loss: 1.238845, Accuracy: 42.71%
# Batch 7, Loss: 1.189192, Accuracy: 42.93%
# Training - Epoch 30, Loss: 1.261750, Accuracy: 42.93%
# Validation Batch 1, Loss: 1.340154, Accuracy: 29.41%
# Validation - Epoch 30, Loss: 1.340154, Accuracy: 29.41%
# Patience—19
# Epoch 31
# Batch 1, Loss: 1.249495, Accuracy: 50.00%
# Batch 2, Loss: 1.271388, Accuracy: 46.88%
# Batch 3, Loss: 1.288811, Accuracy: 47.40%
# Batch 4, Loss: 1.242701, Accuracy: 47.27%
# Batch 5, Loss: 1.235238, Accuracy: 46.88%
# Batch 6, Loss: 1.232025, Accuracy: 46.61%
# Batch 7, Loss: 1.316937, Accuracy: 45.61%
# Training - Epoch 31, Loss: 1.262371, Accuracy: 45.61%
# Validation Batch 1, Loss: 1.345948, Accuracy: 29.41%
# Validation - Epoch 31, Loss: 1.345948, Accuracy: 29.41%
# Patience—20
# Early stopping at epoch 31

# %%
import matplotlib.pyplot as plt

plt.plot(train_accuracy_list, label='Train Accuracy')

# Plotting the second graph
plt.plot(val_accuracy_list, label='Val Accuracy')

# Adding labels and a legend
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Train vs Val Accuracy')
plt.legend()

# Display the plot
plt.show()

plt.plot(train_loss_list, label='Train Loss')

# Plotting the second graph
plt.plot(val_loss_list, label='Val Loss')

# Adding labels and a legend
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train vs Val Loss')
plt.legend()

# Display the plot
plt.show()

# %%
model.eval()

test_loss = 0.0
test_correct = 0
test_total = 0
all_predictions = []
all_labels = []

with torch.no_grad():
    for batch_idx, (images, labels) in enumerate(test_loader):
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)

        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

        print(f"Test Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * test_correct / test_total:.2f}%")

test_loss /= len(test_loader)
test_accuracy = 100 * test_correct / test_total

print(f"Test Set - Loss: {test_loss:.6f}, Accuracy: {test_accuracy:.2f}%")

cm = confusion_matrix(all_labels, all_predictions)
print("Confusion Matrix:")
print(cm)
# Out:
# Test Batch 1, Loss: 1.329596, Accuracy: 30.77%
# Test Set - Loss: 1.329596, Accuracy: 30.77%
# Confusion Matrix:
# [[ 0  0  4  0]
#  [ 0  0 15  0]
#  [ 0  0 16  0]
#  [ 0  1 16  0]]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score

cm = confusion_matrix(all_labels, all_predictions)

# Calculate accuracy
accuracy = accuracy_score(all_labels, all_predictions)

# Calculate percentages for each element
cm_percentage = (cm / np.sum(cm)) * 100

# Plot confusion matrix with count and percentages
fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=['MILD', 'MODERATE', 'NORMAL', 'SEVERE'],
            yticklabels=['MILD', 'MODERATE', 'NORMAL', 'SEVERE'],
            ax=ax)

# Annotate each box with count and percentage
for i in range(len(cm)):
    for j in range(len(cm[0])):
        ax.text(j + 0.5, i + 0.5, f'\n\n{cm_percentage[i, j]:.2f}%',
                ha='center', va='center', color='black')

plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.31

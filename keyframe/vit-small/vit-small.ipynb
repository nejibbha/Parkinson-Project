# %%
import timm
import torch
import copy
from torch.utils.data import DataLoader, random_split
from sklearn.metrics import confusion_matrix
from torchvision import transforms, datasets
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def create_vit(model_name):
    if model_name == 'tiny': model = timm.create_model('vit_tiny_patch16_224', pretrained=False, num_classes=4)
    if model_name == 'small': model = timm.create_model('vit_small_patch16_224', pretrained=False, num_classes=4)
    if model_name == 'base': model = timm.create_model('vit_base_patch16_224', pretrained=False, num_classes=4)

    return model

# %%
transform = transforms.Compose([transforms.Resize((224, 224)), transforms.ToTensor(), transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])])

dataset = datasets.ImageFolder(root='/home/ubuntu/Parkinson-Project/keyframes/energy_images', transform=transform)

total_size = len(dataset)
train_size = int(total_size * 0.8) 
validation_size = int(total_size * 0.1) 
test_size = total_size - train_size - validation_size
generator = torch.Generator().manual_seed(0) 
train_dataset, validation_dataset, test_dataset = random_split(dataset, [train_size, validation_size, test_size], generator=generator)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(validation_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
experiment = 'vit-small-130-epochs-early-stopping-keyframes'

# %%
model_type = 'small'
model = create_vit(model_type)

# Model summary to check architecture
print(model)
# Out:
# VisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 384, kernel_size=(16, 16), stride=(16, 16))
#     (norm): Identity()
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (patch_drop): Identity()
#   (norm_pre): Identity()
#   (blocks): Sequential(
#     (0): Block(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (4): Block(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (5): Block(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (6): Block(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (7): Block(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (8): Block(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (9): Block(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (10): Block(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (11): Block(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#   (fc_norm): Identity()
#   (head_drop): Dropout(p=0.0, inplace=False)
#   (head): Linear(in_features=384, out_features=4, bias=True)
# )

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model.to(device)

num_epochs = 130  
patience = 20  
best_val_loss = float('inf')  
best_model = None  

train_loss_list = list()
val_loss_list = list()
train_accuracy_list = list()
val_accuracy_list = list()

for epoch in range(num_epochs):
    model.train() 
    running_loss = 0.0
    correct = 0
    total = 0
    print(f"Epoch {epoch+1}")

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)  

        optimizer.zero_grad()  
        outputs = model(images)  
        loss = criterion(outputs, labels)  
        loss.backward() 
        optimizer.step() 

        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        print(f"Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * correct / total:.2f}%")

    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct / total
    print(f"Training - Epoch {epoch+1}, Loss: {train_loss:.6f}, Accuracy: {train_accuracy:.2f}%")

    train_loss_list.append(train_loss)
    train_accuracy_list.append(train_accuracy)

    # Validation step
    model.eval()  
    val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():  
        for batch_idx, (images, labels) in enumerate(val_loader):
            images, labels = images.to(device), labels.to(device)  

            outputs = model(images) 
            loss = criterion(outputs, labels) 

            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

            print(f"Validation Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * val_correct / val_total:.2f}%")

    val_loss /= len(val_loader)
    val_accuracy = 100 * val_correct / val_total
    print(f"Validation - Epoch {epoch+1}, Loss: {val_loss:.6f}, Accuracy: {val_accuracy:.2f}%")

    val_loss_list.append(val_loss)
    val_accuracy_list.append(val_accuracy)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = copy.deepcopy(model)
        patience_counter = 0
    else:
        patience_counter += 1

    print(f'Patience—{patience_counter}')

    # Check for early stopping
    if patience_counter >= patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

model = best_model
torch.save(model.state_dict(), f'{experiment}-{model_type}')
# Out:
# Using device: cuda:0
# Epoch 1
# Batch 1, Loss: 1.268087, Accuracy: 39.06%
# Batch 2, Loss: 1.592076, Accuracy: 33.59%
# Batch 3, Loss: 1.569323, Accuracy: 35.94%
# Batch 4, Loss: 1.851887, Accuracy: 33.98%
# Batch 5, Loss: 1.848461, Accuracy: 34.06%
# Batch 6, Loss: 1.593416, Accuracy: 34.11%
# Batch 7, Loss: 1.403208, Accuracy: 33.90%
# Training - Epoch 1, Loss: 1.589494, Accuracy: 33.90%
# Validation Batch 1, Loss: 1.129744, Accuracy: 27.45%
# Validation - Epoch 1, Loss: 1.129744, Accuracy: 27.45%
# Patience—0
# Epoch 2
# Batch 1, Loss: 1.427212, Accuracy: 23.44%
# Batch 2, Loss: 1.169086, Accuracy: 29.69%
# Batch 3, Loss: 1.383717, Accuracy: 31.25%
# Batch 4, Loss: 1.521779, Accuracy: 32.81%
# Batch 5, Loss: 1.399641, Accuracy: 33.12%
# Batch 6, Loss: 1.331756, Accuracy: 33.07%
# Batch 7, Loss: 1.445722, Accuracy: 31.95%
# Training - Epoch 2, Loss: 1.382702, Accuracy: 31.95%
# Validation Batch 1, Loss: 1.202729, Accuracy: 52.94%
# Validation - Epoch 2, Loss: 1.202729, Accuracy: 52.94%
# Patience—1
# Epoch 3
# Batch 1, Loss: 1.239765, Accuracy: 42.19%
# Batch 2, Loss: 1.391097, Accuracy: 32.81%
# Batch 3, Loss: 1.339517, Accuracy: 33.85%
# Batch 4, Loss: 1.488932, Accuracy: 30.08%
# Batch 5, Loss: 1.319989, Accuracy: 31.56%
# Batch 6, Loss: 1.330307, Accuracy: 32.03%
# Batch 7, Loss: 1.360901, Accuracy: 31.22%
# Training - Epoch 3, Loss: 1.352930, Accuracy: 31.22%
# Validation Batch 1, Loss: 1.277640, Accuracy: 19.61%
# Validation - Epoch 3, Loss: 1.277640, Accuracy: 19.61%
# Patience—2
# Epoch 4
# Batch 1, Loss: 1.333928, Accuracy: 29.69%
# Batch 2, Loss: 1.292645, Accuracy: 33.59%
# Batch 3, Loss: 1.301616, Accuracy: 31.77%
# Batch 4, Loss: 1.352482, Accuracy: 31.64%
# Batch 5, Loss: 1.293086, Accuracy: 31.88%
# Batch 6, Loss: 1.251795, Accuracy: 33.85%
# Batch 7, Loss: 1.303856, Accuracy: 33.90%
# Training - Epoch 4, Loss: 1.304201, Accuracy: 33.90%
# Validation Batch 1, Loss: 1.088707, Accuracy: 52.94%
# Validation - Epoch 4, Loss: 1.088707, Accuracy: 52.94%
# Patience—0
# Epoch 5
# Batch 1, Loss: 1.347809, Accuracy: 31.25%
# Batch 2, Loss: 1.426361, Accuracy: 31.25%
# Batch 3, Loss: 1.191807, Accuracy: 34.38%
# Batch 4, Loss: 1.175257, Accuracy: 35.55%
# Batch 5, Loss: 1.302423, Accuracy: 34.69%
# Batch 6, Loss: 1.306689, Accuracy: 35.94%
# Batch 7, Loss: 1.583440, Accuracy: 35.12%
# Training - Epoch 5, Loss: 1.333398, Accuracy: 35.12%
# Validation Batch 1, Loss: 1.156009, Accuracy: 19.61%
# Validation - Epoch 5, Loss: 1.156009, Accuracy: 19.61%
# Patience—1
# Epoch 6
# Batch 1, Loss: 1.329347, Accuracy: 25.00%
# Batch 2, Loss: 1.230901, Accuracy: 29.69%
# Batch 3, Loss: 1.267917, Accuracy: 29.69%
# Batch 4, Loss: 1.409538, Accuracy: 30.08%
# Batch 5, Loss: 1.259177, Accuracy: 29.69%
# Batch 6, Loss: 1.307382, Accuracy: 30.99%
# Batch 7, Loss: 1.221627, Accuracy: 30.98%
# Training - Epoch 6, Loss: 1.289413, Accuracy: 30.98%
# Validation Batch 1, Loss: 1.153246, Accuracy: 52.94%
# Validation - Epoch 6, Loss: 1.153246, Accuracy: 52.94%
# Patience—2
# Epoch 7
# Batch 1, Loss: 1.265546, Accuracy: 39.06%
# Batch 2, Loss: 1.341093, Accuracy: 34.38%
# Batch 3, Loss: 1.398708, Accuracy: 30.73%
# Batch 4, Loss: 1.240239, Accuracy: 32.81%
# Batch 5, Loss: 1.209980, Accuracy: 34.06%
# Batch 6, Loss: 1.274962, Accuracy: 35.68%
# Batch 7, Loss: 1.333694, Accuracy: 35.37%
# Training - Epoch 7, Loss: 1.294889, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.160131, Accuracy: 52.94%
# Validation - Epoch 7, Loss: 1.160131, Accuracy: 52.94%
# Patience—3
# Epoch 8
# Batch 1, Loss: 1.312541, Accuracy: 28.12%
# Batch 2, Loss: 1.350078, Accuracy: 31.25%
# Batch 3, Loss: 1.278705, Accuracy: 33.85%
# Batch 4, Loss: 1.307005, Accuracy: 34.77%
# Batch 5, Loss: 1.227450, Accuracy: 35.31%
# Batch 6, Loss: 1.270605, Accuracy: 35.68%
# Batch 7, Loss: 1.286021, Accuracy: 35.37%
# Training - Epoch 8, Loss: 1.290344, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.163884, Accuracy: 52.94%
# Validation - Epoch 8, Loss: 1.163884, Accuracy: 52.94%
# Patience—4
# Epoch 9
# Batch 1, Loss: 1.263497, Accuracy: 34.38%
# Batch 2, Loss: 1.264837, Accuracy: 37.50%
# Batch 3, Loss: 1.272440, Accuracy: 38.54%
# Batch 4, Loss: 1.356945, Accuracy: 35.55%
# Batch 5, Loss: 1.276953, Accuracy: 35.00%
# Batch 6, Loss: 1.287377, Accuracy: 35.42%
# Batch 7, Loss: 1.326872, Accuracy: 35.37%
# Training - Epoch 9, Loss: 1.292703, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.155730, Accuracy: 52.94%
# Validation - Epoch 9, Loss: 1.155730, Accuracy: 52.94%
# Patience—5
# Epoch 10
# Batch 1, Loss: 1.251861, Accuracy: 35.94%
# Batch 2, Loss: 1.288037, Accuracy: 35.16%
# Batch 3, Loss: 1.257827, Accuracy: 35.42%
# Batch 4, Loss: 1.324564, Accuracy: 36.33%
# Batch 5, Loss: 1.345768, Accuracy: 36.25%
# Batch 6, Loss: 1.277336, Accuracy: 36.20%
# Batch 7, Loss: 1.261719, Accuracy: 35.37%
# Training - Epoch 10, Loss: 1.286730, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.142180, Accuracy: 52.94%
# Validation - Epoch 10, Loss: 1.142180, Accuracy: 52.94%
# Patience—6
# Epoch 11
# Batch 1, Loss: 1.354890, Accuracy: 29.69%
# Batch 2, Loss: 1.259520, Accuracy: 33.59%
# Batch 3, Loss: 1.318624, Accuracy: 34.90%
# Batch 4, Loss: 1.219974, Accuracy: 35.16%
# Batch 5, Loss: 1.291578, Accuracy: 35.62%
# Batch 6, Loss: 1.253379, Accuracy: 35.68%
# Batch 7, Loss: 1.397481, Accuracy: 35.37%
# Training - Epoch 11, Loss: 1.299349, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.162511, Accuracy: 52.94%
# Validation - Epoch 11, Loss: 1.162511, Accuracy: 52.94%
# Patience—7
# Epoch 12
# Batch 1, Loss: 1.286434, Accuracy: 37.50%
# Batch 2, Loss: 1.330541, Accuracy: 33.59%
# Batch 3, Loss: 1.275887, Accuracy: 32.81%
# Batch 4, Loss: 1.299588, Accuracy: 33.98%
# Batch 5, Loss: 1.242161, Accuracy: 36.25%
# Batch 6, Loss: 1.311174, Accuracy: 35.16%
# Batch 7, Loss: 1.273462, Accuracy: 35.37%
# Training - Epoch 12, Loss: 1.288464, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.149126, Accuracy: 52.94%
# Validation - Epoch 12, Loss: 1.149126, Accuracy: 52.94%
# Patience—8
# Epoch 13
# Batch 1, Loss: 1.267394, Accuracy: 34.38%
# Batch 2, Loss: 1.338263, Accuracy: 37.50%
# Batch 3, Loss: 1.261917, Accuracy: 36.98%
# Batch 4, Loss: 1.237222, Accuracy: 37.50%
# Batch 5, Loss: 1.316517, Accuracy: 37.19%
# Batch 6, Loss: 1.264203, Accuracy: 36.72%
# Batch 7, Loss: 1.412980, Accuracy: 35.37%
# Training - Epoch 13, Loss: 1.299785, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.153649, Accuracy: 52.94%
# Validation - Epoch 13, Loss: 1.153649, Accuracy: 52.94%
# Patience—9
# Epoch 14
# Batch 1, Loss: 1.288244, Accuracy: 37.50%
# Batch 2, Loss: 1.295368, Accuracy: 36.72%
# Batch 3, Loss: 1.292573, Accuracy: 33.85%
# Batch 4, Loss: 1.349663, Accuracy: 32.42%
# Batch 5, Loss: 1.329807, Accuracy: 31.56%
# Batch 6, Loss: 1.243805, Accuracy: 31.77%
# Batch 7, Loss: 1.226892, Accuracy: 31.22%
# Training - Epoch 14, Loss: 1.289479, Accuracy: 31.22%
# Validation Batch 1, Loss: 1.187121, Accuracy: 19.61%
# Validation - Epoch 14, Loss: 1.187121, Accuracy: 19.61%
# Patience—10
# Epoch 15
# Batch 1, Loss: 1.324170, Accuracy: 32.81%
# Batch 2, Loss: 1.254331, Accuracy: 36.72%
# Batch 3, Loss: 1.220237, Accuracy: 36.98%
# Batch 4, Loss: 1.337737, Accuracy: 35.94%
# Batch 5, Loss: 1.314970, Accuracy: 37.19%
# Batch 6, Loss: 1.313488, Accuracy: 35.42%
# Batch 7, Loss: 1.328888, Accuracy: 35.61%
# Training - Epoch 15, Loss: 1.299117, Accuracy: 35.61%
# Validation Batch 1, Loss: 1.105923, Accuracy: 52.94%
# Validation - Epoch 15, Loss: 1.105923, Accuracy: 52.94%
# Patience—11
# Epoch 16
# Batch 1, Loss: 1.256495, Accuracy: 39.06%
# Batch 2, Loss: 1.315575, Accuracy: 35.94%
# Batch 3, Loss: 1.350987, Accuracy: 35.42%
# Batch 4, Loss: 1.281702, Accuracy: 33.20%
# Batch 5, Loss: 1.275550, Accuracy: 35.00%
# Batch 6, Loss: 1.285261, Accuracy: 33.85%
# Batch 7, Loss: 1.281606, Accuracy: 33.90%
# Training - Epoch 16, Loss: 1.292454, Accuracy: 33.90%
# Validation Batch 1, Loss: 1.197133, Accuracy: 19.61%
# Validation - Epoch 16, Loss: 1.197133, Accuracy: 19.61%
# Patience—12
# Epoch 17
# Batch 1, Loss: 1.227431, Accuracy: 29.69%
# Batch 2, Loss: 1.324106, Accuracy: 32.03%
# Batch 3, Loss: 1.413978, Accuracy: 30.21%
# Batch 4, Loss: 1.275639, Accuracy: 27.73%
# Batch 5, Loss: 1.299695, Accuracy: 29.06%
# Batch 6, Loss: 1.221390, Accuracy: 30.47%
# Batch 7, Loss: 1.267925, Accuracy: 30.73%
# Training - Epoch 17, Loss: 1.290024, Accuracy: 30.73%
# Validation Batch 1, Loss: 1.147803, Accuracy: 52.94%
# Validation - Epoch 17, Loss: 1.147803, Accuracy: 52.94%
# Patience—13
# Epoch 18
# Batch 1, Loss: 1.320022, Accuracy: 32.81%
# Batch 2, Loss: 1.320631, Accuracy: 29.69%
# Batch 3, Loss: 1.277774, Accuracy: 32.81%
# Batch 4, Loss: 1.273978, Accuracy: 34.77%
# Batch 5, Loss: 1.238414, Accuracy: 35.62%
# Batch 6, Loss: 1.329782, Accuracy: 35.94%
# Batch 7, Loss: 1.234444, Accuracy: 35.37%
# Training - Epoch 18, Loss: 1.285006, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.153613, Accuracy: 52.94%
# Validation - Epoch 18, Loss: 1.153613, Accuracy: 52.94%
# Patience—14
# Epoch 19
# Batch 1, Loss: 1.346364, Accuracy: 35.94%
# Batch 2, Loss: 1.309900, Accuracy: 32.81%
# Batch 3, Loss: 1.344782, Accuracy: 32.29%
# Batch 4, Loss: 1.191807, Accuracy: 33.20%
# Batch 5, Loss: 1.351115, Accuracy: 31.56%
# Batch 6, Loss: 1.231031, Accuracy: 31.77%
# Batch 7, Loss: 1.216175, Accuracy: 32.20%
# Training - Epoch 19, Loss: 1.284453, Accuracy: 32.20%
# Validation Batch 1, Loss: 1.171852, Accuracy: 21.57%
# Validation - Epoch 19, Loss: 1.171852, Accuracy: 21.57%
# Patience—15
# Epoch 20
# Batch 1, Loss: 1.309935, Accuracy: 29.69%
# Batch 2, Loss: 1.291198, Accuracy: 32.81%
# Batch 3, Loss: 1.214929, Accuracy: 34.90%
# Batch 4, Loss: 1.344774, Accuracy: 35.16%
# Batch 5, Loss: 1.287490, Accuracy: 35.00%
# Batch 6, Loss: 1.310505, Accuracy: 34.38%
# Batch 7, Loss: 1.271055, Accuracy: 34.15%
# Training - Epoch 20, Loss: 1.289984, Accuracy: 34.15%
# Validation Batch 1, Loss: 1.129411, Accuracy: 52.94%
# Validation - Epoch 20, Loss: 1.129411, Accuracy: 52.94%
# Patience—16
# Epoch 21
# Batch 1, Loss: 1.303039, Accuracy: 28.12%
# Batch 2, Loss: 1.267878, Accuracy: 35.16%
# Batch 3, Loss: 1.352066, Accuracy: 35.42%
# Batch 4, Loss: 1.260791, Accuracy: 35.16%
# Batch 5, Loss: 1.291860, Accuracy: 33.12%
# Batch 6, Loss: 1.264485, Accuracy: 32.55%
# Batch 7, Loss: 1.337399, Accuracy: 32.68%
# Training - Epoch 21, Loss: 1.296788, Accuracy: 32.68%
# Validation Batch 1, Loss: 1.153895, Accuracy: 52.94%
# Validation - Epoch 21, Loss: 1.153895, Accuracy: 52.94%
# Patience—17
# Epoch 22
# Batch 1, Loss: 1.292132, Accuracy: 26.56%
# Batch 2, Loss: 1.309269, Accuracy: 29.69%
# Batch 3, Loss: 1.287652, Accuracy: 27.60%
# Batch 4, Loss: 1.267808, Accuracy: 27.34%
# Batch 5, Loss: 1.263009, Accuracy: 26.56%
# Batch 6, Loss: 1.369962, Accuracy: 25.52%
# Batch 7, Loss: 1.212938, Accuracy: 26.59%
# Training - Epoch 22, Loss: 1.286110, Accuracy: 26.59%
# Validation Batch 1, Loss: 1.147079, Accuracy: 52.94%
# Validation - Epoch 22, Loss: 1.147079, Accuracy: 52.94%
# Patience—18
# Epoch 23
# Batch 1, Loss: 1.338531, Accuracy: 42.19%
# Batch 2, Loss: 1.335706, Accuracy: 36.72%
# Batch 3, Loss: 1.262980, Accuracy: 38.02%
# Batch 4, Loss: 1.346138, Accuracy: 35.94%
# Batch 5, Loss: 1.263318, Accuracy: 35.31%
# Batch 6, Loss: 1.272265, Accuracy: 35.42%
# Batch 7, Loss: 1.287477, Accuracy: 35.37%
# Training - Epoch 23, Loss: 1.300917, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.146683, Accuracy: 52.94%
# Validation - Epoch 23, Loss: 1.146683, Accuracy: 52.94%
# Patience—19
# Epoch 24
# Batch 1, Loss: 1.313158, Accuracy: 28.12%
# Batch 2, Loss: 1.273731, Accuracy: 36.72%
# Batch 3, Loss: 1.319411, Accuracy: 42.19%
# Batch 4, Loss: 1.261773, Accuracy: 41.41%
# Batch 5, Loss: 1.310795, Accuracy: 38.44%
# Batch 6, Loss: 1.282362, Accuracy: 38.28%
# Batch 7, Loss: 1.236696, Accuracy: 38.05%
# Training - Epoch 24, Loss: 1.285418, Accuracy: 38.05%
# Validation Batch 1, Loss: 1.156866, Accuracy: 52.94%
# Validation - Epoch 24, Loss: 1.156866, Accuracy: 52.94%
# Patience—20
# Early stopping at epoch 24

# %%
import matplotlib.pyplot as plt

plt.plot(train_accuracy_list, label='Train Accuracy')

# Plotting the second graph
plt.plot(val_accuracy_list, label='Val Accuracy')

# Adding labels and a legend
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Train vs Val Accuracy')
plt.legend()

# Display the plot
plt.show()

plt.plot(train_loss_list, label='Train Loss')

# Plotting the second graph
plt.plot(val_loss_list, label='Val Loss')

# Adding labels and a legend
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train vs Val Loss')
plt.legend()

# Display the plot
plt.show()

# %%
model.eval()

test_loss = 0.0
test_correct = 0
test_total = 0
all_predictions = []
all_labels = []

with torch.no_grad():
    for batch_idx, (images, labels) in enumerate(test_loader):
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)

        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

        print(f"Test Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * test_correct / test_total:.2f}%")

test_loss /= len(test_loader)
test_accuracy = 100 * test_correct / test_total

print(f"Test Set - Loss: {test_loss:.6f}, Accuracy: {test_accuracy:.2f}%")

cm = confusion_matrix(all_labels, all_predictions)
print("Confusion Matrix:")
print(cm)
# Out:
# Test Batch 1, Loss: 1.311421, Accuracy: 32.69%
# Test Set - Loss: 1.311421, Accuracy: 32.69%
# Confusion Matrix:
# [[ 0  0  0  4]
#  [ 0  0  0 15]
#  [ 0  0  0 16]
#  [ 0  0  0 17]]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score

cm = confusion_matrix(all_labels, all_predictions)

# Calculate accuracy
accuracy = accuracy_score(all_labels, all_predictions)

# Calculate percentages for each element
cm_percentage = (cm / np.sum(cm)) * 100

# Plot confusion matrix with count and percentages
fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=['MILD', 'MODERATE', 'NORMAL', 'SEVERE'],
            yticklabels=['MILD', 'MODERATE', 'NORMAL', 'SEVERE'],
            ax=ax)

# Annotate each box with count and percentage
for i in range(len(cm)):
    for j in range(len(cm[0])):
        ax.text(j + 0.5, i + 0.5, f'\n\n{cm_percentage[i, j]:.2f}%',
                ha='center', va='center', color='black')

plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.33

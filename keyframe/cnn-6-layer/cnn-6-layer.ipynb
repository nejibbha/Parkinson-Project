# %%
import timm
import torch
import torch.nn as nn
import copy
from torch.utils.data import DataLoader, random_split
from sklearn.metrics import confusion_matrix
from torchvision import transforms, datasets
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
class CNN_5Layer(nn.Module):
    def __init__(self):
        super(CNN_5Layer, self).__init__()

        self.conv_layers = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),
        )

        dummy_input = torch.randn(1, 3, 224, 224)
        conv_output_size = self._get_conv_output_size(dummy_input)

        self.fc_layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(conv_output_size, 4, bias=True),
            nn.Softmax(dim=1)
        )

        self.l1_regularizer = nn.L1Loss()

    def _get_conv_output_size(self, x):
        with torch.no_grad():
            conv_output = self.conv_layers(x)
        return conv_output.view(x.size(0), -1).shape[1]

    def forward(self, x):
        x = self.conv_layers(x)
        x = self.fc_layers(x)
        return x

# %%
class CNN_6Layer(nn.Module):
    def __init__(self):
        super(CNN_6Layer, self).__init__()

        self.conv_layers = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),
        )

        dummy_input = torch.randn(1, 3, 224, 224)
        conv_output_size = self._get_conv_output_size(dummy_input)

        self.fc_layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(conv_output_size, 4, bias=True),
            nn.Softmax(dim=1)
        )

        self.l1_regularizer = nn.L1Loss()

    def _get_conv_output_size(self, x):
        with torch.no_grad():
            conv_output = self.conv_layers(x)
        return conv_output.view(x.size(0), -1).shape[1]

    def forward(self, x):
        x = self.conv_layers(x)
        x = self.fc_layers(x)
        return x

# %%
def create_cnn(model_name):
    if model_name == '5-layer': model = CNN_5Layer()
    if model_name == '6-layer': model = CNN_6Layer()

    return model

# %%
transform = transforms.Compose([transforms.Resize((224, 224)), transforms.ToTensor(), transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])])

dataset = datasets.ImageFolder(root='/home/ubuntu/Parkinson-Project/keyframes/energy_images', transform=transform)

total_size = len(dataset)
train_size = int(total_size * 0.8) 
validation_size = int(total_size * 0.1) 
test_size = total_size - train_size - validation_size
generator = torch.Generator().manual_seed(0) 
train_dataset, validation_dataset, test_dataset = random_split(dataset, [train_size, validation_size, test_size], generator=generator)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(validation_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
experiment = 'cnn-6-layer-130-epochs-early-stopping-with-regularization-keyframes'

# %%
model_type = '6-layer'
model = create_cnn(model_type)

# Model summary to check architecture
print(model)
# Out:
# CNN_6Layer(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.5, inplace=False)
#     (5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Dropout(p=0.5, inplace=False)
#     (10): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Dropout(p=0.5, inplace=False)
#     (15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Dropout(p=0.5, inplace=False)
#     (20): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): ReLU()
#     (22): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Dropout(p=0.5, inplace=False)
#   )
#   (fc_layers): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=3136, out_features=4, bias=True)
#     (2): Softmax(dim=1)
#   )
#   (l1_regularizer): L1Loss()
# )

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model.to(device)

num_epochs = 130  
patience = 20  
best_val_loss = float('inf')  
best_model = None  

train_loss_list = list()
val_loss_list = list()
train_accuracy_list = list()
val_accuracy_list = list()

for epoch in range(num_epochs):
    model.train() 
    running_loss = 0.0
    correct = 0
    total = 0
    print(f"Epoch {epoch+1}")

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)  

        optimizer.zero_grad()  
        outputs = model(images)  
        loss = criterion(outputs, labels)  
        loss.backward() 
        optimizer.step() 

        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        print(f"Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * correct / total:.2f}%")

    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct / total
    print(f"Training - Epoch {epoch+1}, Loss: {train_loss:.6f}, Accuracy: {train_accuracy:.2f}%")

    train_loss_list.append(train_loss)
    train_accuracy_list.append(train_accuracy)

    # Validation step
    model.eval()  
    val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():  
        for batch_idx, (images, labels) in enumerate(val_loader):
            images, labels = images.to(device), labels.to(device)  

            outputs = model(images) 
            loss = criterion(outputs, labels) 

            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

            print(f"Validation Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * val_correct / val_total:.2f}%")

    val_loss /= len(val_loader)
    val_accuracy = 100 * val_correct / val_total
    print(f"Validation - Epoch {epoch+1}, Loss: {val_loss:.6f}, Accuracy: {val_accuracy:.2f}%")

    val_loss_list.append(val_loss)
    val_accuracy_list.append(val_accuracy)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = copy.deepcopy(model)
        patience_counter = 0
    else:
        patience_counter += 1

    print(f'Patience—{patience_counter}')

    # Check for early stopping
    if patience_counter >= patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

model = best_model
torch.save(model.state_dict(), f'{experiment}-{model_type}')
# Out:
# Using device: cuda:0
# Epoch 1
# Batch 1, Loss: 1.394421, Accuracy: 25.00%
# Batch 2, Loss: 1.381347, Accuracy: 28.12%
# Batch 3, Loss: 1.424794, Accuracy: 26.56%
# Batch 4, Loss: 1.429113, Accuracy: 26.56%
# Batch 5, Loss: 1.360860, Accuracy: 27.19%
# Batch 6, Loss: 1.377185, Accuracy: 27.34%
# Batch 7, Loss: 1.351996, Accuracy: 27.32%
# Training - Epoch 1, Loss: 1.388531, Accuracy: 27.32%
# Validation Batch 1, Loss: 1.390219, Accuracy: 0.00%
# Validation - Epoch 1, Loss: 1.390219, Accuracy: 0.00%
# Patience—0
# Epoch 2
# Batch 1, Loss: 1.352253, Accuracy: 32.81%
# Batch 2, Loss: 1.359479, Accuracy: 32.81%
# Batch 3, Loss: 1.390433, Accuracy: 30.21%
# Batch 4, Loss: 1.342989, Accuracy: 31.25%
# Batch 5, Loss: 1.377429, Accuracy: 30.31%
# Batch 6, Loss: 1.374440, Accuracy: 30.73%
# Batch 7, Loss: 1.367720, Accuracy: 30.98%
# Training - Epoch 2, Loss: 1.366392, Accuracy: 30.98%
# Validation Batch 1, Loss: 1.399024, Accuracy: 0.00%
# Validation - Epoch 2, Loss: 1.399024, Accuracy: 0.00%
# Patience—1
# Epoch 3
# Batch 1, Loss: 1.317011, Accuracy: 39.06%
# Batch 2, Loss: 1.346223, Accuracy: 36.72%
# Batch 3, Loss: 1.403726, Accuracy: 34.38%
# Batch 4, Loss: 1.361040, Accuracy: 33.59%
# Batch 5, Loss: 1.335114, Accuracy: 33.75%
# Batch 6, Loss: 1.301226, Accuracy: 34.64%
# Batch 7, Loss: 1.296704, Accuracy: 35.85%
# Training - Epoch 3, Loss: 1.337292, Accuracy: 35.85%
# Validation Batch 1, Loss: 1.406366, Accuracy: 0.00%
# Validation - Epoch 3, Loss: 1.406366, Accuracy: 0.00%
# Patience—2
# Epoch 4
# Batch 1, Loss: 1.309852, Accuracy: 40.62%
# Batch 2, Loss: 1.373863, Accuracy: 35.94%
# Batch 3, Loss: 1.366483, Accuracy: 34.38%
# Batch 4, Loss: 1.293031, Accuracy: 37.11%
# Batch 5, Loss: 1.326888, Accuracy: 37.81%
# Batch 6, Loss: 1.287308, Accuracy: 37.76%
# Batch 7, Loss: 1.285455, Accuracy: 38.05%
# Training - Epoch 4, Loss: 1.320411, Accuracy: 38.05%
# Validation Batch 1, Loss: 1.411478, Accuracy: 0.00%
# Validation - Epoch 4, Loss: 1.411478, Accuracy: 0.00%
# Patience—3
# Epoch 5
# Batch 1, Loss: 1.354965, Accuracy: 32.81%
# Batch 2, Loss: 1.366764, Accuracy: 28.91%
# Batch 3, Loss: 1.337788, Accuracy: 29.69%
# Batch 4, Loss: 1.373104, Accuracy: 29.69%
# Batch 5, Loss: 1.343235, Accuracy: 29.38%
# Batch 6, Loss: 1.336384, Accuracy: 30.21%
# Batch 7, Loss: 1.339576, Accuracy: 30.00%
# Training - Epoch 5, Loss: 1.350260, Accuracy: 30.00%
# Validation Batch 1, Loss: 1.413174, Accuracy: 0.00%
# Validation - Epoch 5, Loss: 1.413174, Accuracy: 0.00%
# Patience—4
# Epoch 6
# Batch 1, Loss: 1.334141, Accuracy: 35.94%
# Batch 2, Loss: 1.256770, Accuracy: 42.19%
# Batch 3, Loss: 1.382498, Accuracy: 38.02%
# Batch 4, Loss: 1.340084, Accuracy: 38.67%
# Batch 5, Loss: 1.273840, Accuracy: 40.00%
# Batch 6, Loss: 1.351252, Accuracy: 39.06%
# Batch 7, Loss: 1.175365, Accuracy: 40.24%
# Training - Epoch 6, Loss: 1.301993, Accuracy: 40.24%
# Validation Batch 1, Loss: 1.411568, Accuracy: 0.00%
# Validation - Epoch 6, Loss: 1.411568, Accuracy: 0.00%
# Patience—5
# Epoch 7
# Batch 1, Loss: 1.297783, Accuracy: 40.62%
# Batch 2, Loss: 1.335907, Accuracy: 39.06%
# Batch 3, Loss: 1.305341, Accuracy: 40.10%
# Batch 4, Loss: 1.414946, Accuracy: 35.94%
# Batch 5, Loss: 1.378719, Accuracy: 35.31%
# Batch 6, Loss: 1.330822, Accuracy: 35.94%
# Batch 7, Loss: 1.299643, Accuracy: 36.59%
# Training - Epoch 7, Loss: 1.337595, Accuracy: 36.59%
# Validation Batch 1, Loss: 1.408806, Accuracy: 0.00%
# Validation - Epoch 7, Loss: 1.408806, Accuracy: 0.00%
# Patience—6
# Epoch 8
# Batch 1, Loss: 1.297480, Accuracy: 39.06%
# Batch 2, Loss: 1.354513, Accuracy: 32.03%
# Batch 3, Loss: 1.336406, Accuracy: 33.33%
# Batch 4, Loss: 1.328517, Accuracy: 33.59%
# Batch 5, Loss: 1.357184, Accuracy: 34.06%
# Batch 6, Loss: 1.330906, Accuracy: 33.59%
# Batch 7, Loss: 1.347073, Accuracy: 34.15%
# Training - Epoch 8, Loss: 1.336011, Accuracy: 34.15%
# Validation Batch 1, Loss: 1.406268, Accuracy: 0.00%
# Validation - Epoch 8, Loss: 1.406268, Accuracy: 0.00%
# Patience—7
# Epoch 9
# Batch 1, Loss: 1.375461, Accuracy: 31.25%
# Batch 2, Loss: 1.352435, Accuracy: 32.81%
# Batch 3, Loss: 1.375396, Accuracy: 29.69%
# Batch 4, Loss: 1.326693, Accuracy: 31.25%
# Batch 5, Loss: 1.270651, Accuracy: 33.12%
# Batch 6, Loss: 1.327887, Accuracy: 33.33%
# Batch 7, Loss: 1.301246, Accuracy: 33.41%
# Training - Epoch 9, Loss: 1.332824, Accuracy: 33.41%
# Validation Batch 1, Loss: 1.403163, Accuracy: 3.92%
# Validation - Epoch 9, Loss: 1.403163, Accuracy: 3.92%
# Patience—8
# Epoch 10
# Batch 1, Loss: 1.336284, Accuracy: 39.06%
# Batch 2, Loss: 1.342944, Accuracy: 36.72%
# Batch 3, Loss: 1.348642, Accuracy: 35.42%
# Batch 4, Loss: 1.297456, Accuracy: 36.72%
# Batch 5, Loss: 1.370905, Accuracy: 35.31%
# Batch 6, Loss: 1.358261, Accuracy: 34.11%
# Batch 7, Loss: 1.333542, Accuracy: 34.39%
# Training - Epoch 10, Loss: 1.341148, Accuracy: 34.39%
# Validation Batch 1, Loss: 1.399763, Accuracy: 25.49%
# Validation - Epoch 10, Loss: 1.399763, Accuracy: 25.49%
# Patience—9
# Epoch 11
# Batch 1, Loss: 1.318287, Accuracy: 34.38%
# Batch 2, Loss: 1.306803, Accuracy: 35.94%
# Batch 3, Loss: 1.346455, Accuracy: 34.90%
# Batch 4, Loss: 1.381076, Accuracy: 33.59%
# Batch 5, Loss: 1.319272, Accuracy: 35.62%
# Batch 6, Loss: 1.293219, Accuracy: 36.46%
# Batch 7, Loss: 1.417874, Accuracy: 36.34%
# Training - Epoch 11, Loss: 1.340427, Accuracy: 36.34%
# Validation Batch 1, Loss: 1.396017, Accuracy: 27.45%
# Validation - Epoch 11, Loss: 1.396017, Accuracy: 27.45%
# Patience—10
# Epoch 12
# Batch 1, Loss: 1.315260, Accuracy: 40.62%
# Batch 2, Loss: 1.341417, Accuracy: 36.72%
# Batch 3, Loss: 1.368331, Accuracy: 33.33%
# Batch 4, Loss: 1.267005, Accuracy: 35.55%
# Batch 5, Loss: 1.292932, Accuracy: 37.19%
# Batch 6, Loss: 1.467835, Accuracy: 34.11%
# Batch 7, Loss: 1.395171, Accuracy: 33.41%
# Training - Epoch 12, Loss: 1.349707, Accuracy: 33.41%
# Validation Batch 1, Loss: 1.394881, Accuracy: 27.45%
# Validation - Epoch 12, Loss: 1.394881, Accuracy: 27.45%
# Patience—11
# Epoch 13
# Batch 1, Loss: 1.335580, Accuracy: 35.94%
# Batch 2, Loss: 1.373023, Accuracy: 32.81%
# Batch 3, Loss: 1.324386, Accuracy: 32.81%
# Batch 4, Loss: 1.320488, Accuracy: 32.42%
# Batch 5, Loss: 1.279249, Accuracy: 35.00%
# Batch 6, Loss: 1.325074, Accuracy: 34.90%
# Batch 7, Loss: 1.217697, Accuracy: 36.10%
# Training - Epoch 13, Loss: 1.310785, Accuracy: 36.10%
# Validation Batch 1, Loss: 1.394947, Accuracy: 27.45%
# Validation - Epoch 13, Loss: 1.394947, Accuracy: 27.45%
# Patience—12
# Epoch 14
# Batch 1, Loss: 1.311820, Accuracy: 39.06%
# Batch 2, Loss: 1.336849, Accuracy: 38.28%
# Batch 3, Loss: 1.364271, Accuracy: 35.42%
# Batch 4, Loss: 1.338290, Accuracy: 36.72%
# Batch 5, Loss: 1.329086, Accuracy: 36.88%
# Batch 6, Loss: 1.362419, Accuracy: 35.94%
# Batch 7, Loss: 1.343080, Accuracy: 35.85%
# Training - Epoch 14, Loss: 1.340831, Accuracy: 35.85%
# Validation Batch 1, Loss: 1.395279, Accuracy: 29.41%
# Validation - Epoch 14, Loss: 1.395279, Accuracy: 29.41%
# Patience—13
# Epoch 15
# Batch 1, Loss: 1.294629, Accuracy: 40.62%
# Batch 2, Loss: 1.384169, Accuracy: 34.38%
# Batch 3, Loss: 1.329917, Accuracy: 35.42%
# Batch 4, Loss: 1.317469, Accuracy: 35.94%
# Batch 5, Loss: 1.312999, Accuracy: 37.81%
# Batch 6, Loss: 1.330191, Accuracy: 37.76%
# Batch 7, Loss: 1.274584, Accuracy: 38.29%
# Training - Epoch 15, Loss: 1.320565, Accuracy: 38.29%
# Validation Batch 1, Loss: 1.395392, Accuracy: 29.41%
# Validation - Epoch 15, Loss: 1.395392, Accuracy: 29.41%
# Patience—14
# Epoch 16
# Batch 1, Loss: 1.333614, Accuracy: 31.25%
# Batch 2, Loss: 1.303218, Accuracy: 35.16%
# Batch 3, Loss: 1.398270, Accuracy: 33.33%
# Batch 4, Loss: 1.345850, Accuracy: 33.59%
# Batch 5, Loss: 1.348284, Accuracy: 34.38%
# Batch 6, Loss: 1.302731, Accuracy: 34.90%
# Batch 7, Loss: 1.303947, Accuracy: 34.63%
# Training - Epoch 16, Loss: 1.333702, Accuracy: 34.63%
# Validation Batch 1, Loss: 1.395434, Accuracy: 27.45%
# Validation - Epoch 16, Loss: 1.395434, Accuracy: 27.45%
# Patience—15
# Epoch 17
# Batch 1, Loss: 1.318948, Accuracy: 35.94%
# Batch 2, Loss: 1.327827, Accuracy: 37.50%
# Batch 3, Loss: 1.327019, Accuracy: 36.98%
# Batch 4, Loss: 1.286814, Accuracy: 37.89%
# Batch 5, Loss: 1.311508, Accuracy: 37.50%
# Batch 6, Loss: 1.311917, Accuracy: 37.76%
# Batch 7, Loss: 1.384831, Accuracy: 37.07%
# Training - Epoch 17, Loss: 1.324124, Accuracy: 37.07%
# Validation Batch 1, Loss: 1.396003, Accuracy: 27.45%
# Validation - Epoch 17, Loss: 1.396003, Accuracy: 27.45%
# Patience—16
# Epoch 18
# Batch 1, Loss: 1.283250, Accuracy: 45.31%
# Batch 2, Loss: 1.306039, Accuracy: 42.19%
# Batch 3, Loss: 1.373373, Accuracy: 36.98%
# Batch 4, Loss: 1.371333, Accuracy: 34.77%
# Batch 5, Loss: 1.343783, Accuracy: 33.44%
# Batch 6, Loss: 1.346498, Accuracy: 33.07%
# Batch 7, Loss: 1.269064, Accuracy: 33.66%
# Training - Epoch 18, Loss: 1.327620, Accuracy: 33.66%
# Validation Batch 1, Loss: 1.397779, Accuracy: 27.45%
# Validation - Epoch 18, Loss: 1.397779, Accuracy: 27.45%
# Patience—17
# Epoch 19
# Batch 1, Loss: 1.259064, Accuracy: 40.62%
# Batch 2, Loss: 1.324459, Accuracy: 39.84%
# Batch 3, Loss: 1.269915, Accuracy: 41.67%
# Batch 4, Loss: 1.341151, Accuracy: 39.06%
# Batch 5, Loss: 1.370962, Accuracy: 37.50%
# Batch 6, Loss: 1.355716, Accuracy: 36.98%
# Batch 7, Loss: 1.327864, Accuracy: 37.07%
# Training - Epoch 19, Loss: 1.321304, Accuracy: 37.07%
# Validation Batch 1, Loss: 1.398029, Accuracy: 27.45%
# Validation - Epoch 19, Loss: 1.398029, Accuracy: 27.45%
# Patience—18
# Epoch 20
# Batch 1, Loss: 1.292176, Accuracy: 40.62%
# Batch 2, Loss: 1.303954, Accuracy: 37.50%
# Batch 3, Loss: 1.306022, Accuracy: 36.98%
# Batch 4, Loss: 1.375977, Accuracy: 32.81%
# Batch 5, Loss: 1.264818, Accuracy: 35.00%
# Batch 6, Loss: 1.295984, Accuracy: 36.72%
# Batch 7, Loss: 1.311564, Accuracy: 37.07%
# Training - Epoch 20, Loss: 1.307214, Accuracy: 37.07%
# Validation Batch 1, Loss: 1.399271, Accuracy: 27.45%
# Validation - Epoch 20, Loss: 1.399271, Accuracy: 27.45%
# Patience—19
# Epoch 21
# Batch 1, Loss: 1.296761, Accuracy: 32.81%
# Batch 2, Loss: 1.322401, Accuracy: 32.81%
# Batch 3, Loss: 1.343568, Accuracy: 34.90%
# Batch 4, Loss: 1.329519, Accuracy: 33.98%
# Batch 5, Loss: 1.378131, Accuracy: 32.81%
# Batch 6, Loss: 1.274508, Accuracy: 34.64%
# Batch 7, Loss: 1.348150, Accuracy: 34.39%
# Training - Epoch 21, Loss: 1.327577, Accuracy: 34.39%
# Validation Batch 1, Loss: 1.400520, Accuracy: 27.45%
# Validation - Epoch 21, Loss: 1.400520, Accuracy: 27.45%
# Patience—20
# Early stopping at epoch 21

# %%
import matplotlib.pyplot as plt

plt.plot(train_accuracy_list, label='Train Accuracy')

# Plotting the second graph
plt.plot(val_accuracy_list, label='Val Accuracy')

# Adding labels and a legend
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Train vs Val Accuracy')
plt.legend()

# Display the plot
plt.show()

plt.plot(train_loss_list, label='Train Loss')

# Plotting the second graph
plt.plot(val_loss_list, label='Val Loss')

# Adding labels and a legend
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train vs Val Loss')
plt.legend()

# Display the plot
plt.show()

# %%
model.eval()

test_loss = 0.0
test_correct = 0
test_total = 0
all_predictions = []
all_labels = []

with torch.no_grad():
    for batch_idx, (images, labels) in enumerate(test_loader):
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)

        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

        print(f"Test Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * test_correct / test_total:.2f}%")

test_loss /= len(test_loader)
test_accuracy = 100 * test_correct / test_total

print(f"Test Set - Loss: {test_loss:.6f}, Accuracy: {test_accuracy:.2f}%")

cm = confusion_matrix(all_labels, all_predictions)
print("Confusion Matrix:")
print(cm)
# Out:
# Test Batch 1, Loss: 1.395255, Accuracy: 7.69%
# Test Set - Loss: 1.395255, Accuracy: 7.69%
# Confusion Matrix:
# [[ 4  0  0  0]
#  [15  0  0  0]
#  [16  0  0  0]
#  [17  0  0  0]]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score

cm = confusion_matrix(all_labels, all_predictions)

# Calculate accuracy
accuracy = accuracy_score(all_labels, all_predictions)

# Calculate percentages for each element
cm_percentage = (cm / np.sum(cm)) * 100

# Plot confusion matrix with count and percentages
fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=['MILD', 'MODERATE', 'NORMAL', 'SEVERE'],
            yticklabels=['MILD', 'MODERATE', 'NORMAL', 'SEVERE'],
            ax=ax)

# Annotate each box with count and percentage
for i in range(len(cm)):
    for j in range(len(cm[0])):
        ax.text(j + 0.5, i + 0.5, f'\n\n{cm_percentage[i, j]:.2f}%',
                ha='center', va='center', color='black')

plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.08

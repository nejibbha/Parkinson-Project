# %%
import timm
import torch
import copy
from torch.utils.data import DataLoader, random_split
from sklearn.metrics import confusion_matrix
from torchvision import transforms, datasets

# %%
print(timm.__version__)
print(torch.__version__)
# Out:
# 0.9.16
# 2.0.1

# %%
def create_vit(model_name):
    if model_name == 'tiny': model = timm.create_model('vit_tiny_patch16_224', pretrained=False, num_classes=4)
    if model_name == 'small': model = timm.create_model('vit_small_patch16_224', pretrained=False, num_classes=4)
    if model_name == 'base': model = timm.create_model('vit_base_patch16_224', pretrained=False, num_classes=4)

    return model

# %%
transform = transforms.Compose([transforms.Resize((224, 224)), transforms.ToTensor(), transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])])

dataset = datasets.ImageFolder(root='/home/ubuntu/Parkinson-Project/keyframes/energy_images', transform=transform)

total_size = len(dataset)
train_size = int(total_size * 0.8) 
validation_size = int(total_size * 0.1) 
test_size = total_size - train_size - validation_size
generator = torch.Generator().manual_seed(0) 
train_dataset, validation_dataset, test_dataset = random_split(dataset, [train_size, validation_size, test_size], generator=generator)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(validation_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
experiment = 'vit-tiny-130-epochs-early-stopping-keyframes'

# %%
model_type = 'tiny'
model = create_vit(model_type)

# Model summary to check architecture
print(model)
# Out:
# VisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 192, kernel_size=(16, 16), stride=(16, 16))
#     (norm): Identity()
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (patch_drop): Identity()
#   (norm_pre): Identity()
#   (blocks): Sequential(
#     (0): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (4): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (5): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (6): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (7): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (8): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (9): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (10): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (11): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#   (fc_norm): Identity()
#   (head_drop): Dropout(p=0.0, inplace=False)
#   (head): Linear(in_features=192, out_features=4, bias=True)
# )

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model.to(device)

num_epochs = 130  
patience = 20  
best_val_loss = float('inf')  
best_model = None  

train_loss_list = list()
val_loss_list = list()
train_accuracy_list = list()
val_accuracy_list = list()

for epoch in range(num_epochs):
    model.train() 
    running_loss = 0.0
    correct = 0
    total = 0
    print(f"Epoch {epoch+1}")

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)  

        optimizer.zero_grad()  
        outputs = model(images)  
        loss = criterion(outputs, labels)  
        loss.backward() 
        optimizer.step() 

        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        print(f"Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * correct / total:.2f}%")

    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct / total
    print(f"Training - Epoch {epoch+1}, Loss: {train_loss:.6f}, Accuracy: {train_accuracy:.2f}%")
    
    train_loss_list.append(train_loss)
    train_accuracy_list.append(train_accuracy)

    # Validation step
    model.eval()  
    val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():  
        for batch_idx, (images, labels) in enumerate(val_loader):
            images, labels = images.to(device), labels.to(device)  

            outputs = model(images) 
            loss = criterion(outputs, labels) 

            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

            print(f"Validation Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * val_correct / val_total:.2f}%")

    val_loss /= len(val_loader)
    val_accuracy = 100 * val_correct / val_total
    print(f"Validation - Epoch {epoch+1}, Loss: {val_loss:.6f}, Accuracy: {val_accuracy:.2f}%")
    
    val_loss_list.append(val_loss)
    val_accuracy_list.append(val_accuracy)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = copy.deepcopy(model)
        patience_counter = 0
    else:
        patience_counter += 1

    print(f'Patience—{patience_counter}')

    # Check for early stopping
    if patience_counter >= patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

model = best_model
torch.save(model.state_dict(), f'{experiment}-{model_type}')
# Out:
# Using device: cuda:0
# Epoch 1
# Batch 1, Loss: 1.498121, Accuracy: 25.00%
# Batch 2, Loss: 1.304323, Accuracy: 28.12%
# Batch 3, Loss: 1.414036, Accuracy: 28.12%
# Batch 4, Loss: 1.350706, Accuracy: 28.12%
# Batch 5, Loss: 1.279087, Accuracy: 30.31%
# Batch 6, Loss: 1.298878, Accuracy: 30.99%
# Batch 7, Loss: 1.295760, Accuracy: 31.95%
# Training - Epoch 1, Loss: 1.348702, Accuracy: 31.95%
# Validation Batch 1, Loss: 1.107987, Accuracy: 27.45%
# Validation - Epoch 1, Loss: 1.107987, Accuracy: 27.45%
# Patience—0
# Epoch 2
# Batch 1, Loss: 1.245757, Accuracy: 26.56%
# Batch 2, Loss: 1.389499, Accuracy: 25.00%
# Batch 3, Loss: 1.354457, Accuracy: 30.73%
# Batch 4, Loss: 1.282989, Accuracy: 31.64%
# Batch 5, Loss: 1.224323, Accuracy: 32.19%
# Batch 6, Loss: 1.329704, Accuracy: 32.81%
# Batch 7, Loss: 1.381329, Accuracy: 32.20%
# Training - Epoch 2, Loss: 1.315437, Accuracy: 32.20%
# Validation Batch 1, Loss: 1.194816, Accuracy: 19.61%
# Validation - Epoch 2, Loss: 1.194816, Accuracy: 19.61%
# Patience—1
# Epoch 3
# Batch 1, Loss: 1.258291, Accuracy: 40.62%
# Batch 2, Loss: 1.330700, Accuracy: 32.03%
# Batch 3, Loss: 1.261638, Accuracy: 31.77%
# Batch 4, Loss: 1.301663, Accuracy: 31.64%
# Batch 5, Loss: 1.312182, Accuracy: 31.25%
# Batch 6, Loss: 1.327748, Accuracy: 29.95%
# Batch 7, Loss: 1.303562, Accuracy: 30.49%
# Training - Epoch 3, Loss: 1.299398, Accuracy: 30.49%
# Validation Batch 1, Loss: 1.171233, Accuracy: 52.94%
# Validation - Epoch 3, Loss: 1.171233, Accuracy: 52.94%
# Patience—2
# Epoch 4
# Batch 1, Loss: 1.301673, Accuracy: 40.62%
# Batch 2, Loss: 1.336018, Accuracy: 32.81%
# Batch 3, Loss: 1.280126, Accuracy: 32.81%
# Batch 4, Loss: 1.291992, Accuracy: 35.16%
# Batch 5, Loss: 1.236330, Accuracy: 37.19%
# Batch 6, Loss: 1.310213, Accuracy: 35.16%
# Batch 7, Loss: 1.271202, Accuracy: 35.37%
# Training - Epoch 4, Loss: 1.289651, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.140105, Accuracy: 52.94%
# Validation - Epoch 4, Loss: 1.140105, Accuracy: 52.94%
# Patience—3
# Epoch 5
# Batch 1, Loss: 1.250021, Accuracy: 40.62%
# Batch 2, Loss: 1.290531, Accuracy: 39.06%
# Batch 3, Loss: 1.326198, Accuracy: 38.54%
# Batch 4, Loss: 1.275623, Accuracy: 36.72%
# Batch 5, Loss: 1.221809, Accuracy: 36.88%
# Batch 6, Loss: 1.375112, Accuracy: 34.90%
# Batch 7, Loss: 1.322598, Accuracy: 35.37%
# Training - Epoch 5, Loss: 1.294556, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.149933, Accuracy: 52.94%
# Validation - Epoch 5, Loss: 1.149933, Accuracy: 52.94%
# Patience—4
# Epoch 6
# Batch 1, Loss: 1.272097, Accuracy: 42.19%
# Batch 2, Loss: 1.263763, Accuracy: 36.72%
# Batch 3, Loss: 1.316622, Accuracy: 33.85%
# Batch 4, Loss: 1.354558, Accuracy: 35.55%
# Batch 5, Loss: 1.268207, Accuracy: 35.62%
# Batch 6, Loss: 1.320739, Accuracy: 34.90%
# Batch 7, Loss: 1.159786, Accuracy: 35.37%
# Training - Epoch 6, Loss: 1.279396, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.162764, Accuracy: 52.94%
# Validation - Epoch 6, Loss: 1.162764, Accuracy: 52.94%
# Patience—5
# Epoch 7
# Batch 1, Loss: 1.268880, Accuracy: 43.75%
# Batch 2, Loss: 1.260532, Accuracy: 42.97%
# Batch 3, Loss: 1.371699, Accuracy: 39.06%
# Batch 4, Loss: 1.265525, Accuracy: 37.89%
# Batch 5, Loss: 1.334166, Accuracy: 35.62%
# Batch 6, Loss: 1.280632, Accuracy: 35.68%
# Batch 7, Loss: 1.295565, Accuracy: 35.37%
# Training - Epoch 7, Loss: 1.296714, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.138260, Accuracy: 52.94%
# Validation - Epoch 7, Loss: 1.138260, Accuracy: 52.94%
# Patience—6
# Epoch 8
# Batch 1, Loss: 1.352163, Accuracy: 29.69%
# Batch 2, Loss: 1.358820, Accuracy: 31.25%
# Batch 3, Loss: 1.286754, Accuracy: 33.33%
# Batch 4, Loss: 1.230621, Accuracy: 32.03%
# Batch 5, Loss: 1.252097, Accuracy: 31.25%
# Batch 6, Loss: 1.285941, Accuracy: 30.73%
# Batch 7, Loss: 1.267576, Accuracy: 31.22%
# Training - Epoch 8, Loss: 1.290567, Accuracy: 31.22%
# Validation Batch 1, Loss: 1.179878, Accuracy: 21.57%
# Validation - Epoch 8, Loss: 1.179878, Accuracy: 21.57%
# Patience—7
# Epoch 9
# Batch 1, Loss: 1.231722, Accuracy: 37.50%
# Batch 2, Loss: 1.303774, Accuracy: 35.16%
# Batch 3, Loss: 1.306488, Accuracy: 36.98%
# Batch 4, Loss: 1.330220, Accuracy: 36.33%
# Batch 5, Loss: 1.278067, Accuracy: 35.00%
# Batch 6, Loss: 1.287892, Accuracy: 35.16%
# Batch 7, Loss: 1.320965, Accuracy: 34.63%
# Training - Epoch 9, Loss: 1.294161, Accuracy: 34.63%
# Validation Batch 1, Loss: 1.137839, Accuracy: 52.94%
# Validation - Epoch 9, Loss: 1.137839, Accuracy: 52.94%
# Patience—8
# Epoch 10
# Batch 1, Loss: 1.261008, Accuracy: 25.00%
# Batch 2, Loss: 1.349244, Accuracy: 22.66%
# Batch 3, Loss: 1.349694, Accuracy: 26.56%
# Batch 4, Loss: 1.236871, Accuracy: 28.52%
# Batch 5, Loss: 1.336884, Accuracy: 27.81%
# Batch 6, Loss: 1.326854, Accuracy: 26.56%
# Batch 7, Loss: 1.255411, Accuracy: 25.61%
# Training - Epoch 10, Loss: 1.302281, Accuracy: 25.61%
# Validation Batch 1, Loss: 1.166893, Accuracy: 52.94%
# Validation - Epoch 10, Loss: 1.166893, Accuracy: 52.94%
# Patience—9
# Epoch 11
# Batch 1, Loss: 1.233582, Accuracy: 42.19%
# Batch 2, Loss: 1.339209, Accuracy: 42.97%
# Batch 3, Loss: 1.280045, Accuracy: 36.46%
# Batch 4, Loss: 1.278912, Accuracy: 36.72%
# Batch 5, Loss: 1.316595, Accuracy: 35.62%
# Batch 6, Loss: 1.385324, Accuracy: 35.42%
# Batch 7, Loss: 1.258394, Accuracy: 35.37%
# Training - Epoch 11, Loss: 1.298866, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.107877, Accuracy: 52.94%
# Validation - Epoch 11, Loss: 1.107877, Accuracy: 52.94%
# Patience—0
# Epoch 12
# Batch 1, Loss: 1.169805, Accuracy: 48.44%
# Batch 2, Loss: 1.349928, Accuracy: 38.28%
# Batch 3, Loss: 1.384628, Accuracy: 34.38%
# Batch 4, Loss: 1.321040, Accuracy: 32.42%
# Batch 5, Loss: 1.265666, Accuracy: 34.06%
# Batch 6, Loss: 1.269004, Accuracy: 35.68%
# Batch 7, Loss: 1.317577, Accuracy: 35.37%
# Training - Epoch 12, Loss: 1.296807, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.179899, Accuracy: 19.61%
# Validation - Epoch 12, Loss: 1.179899, Accuracy: 19.61%
# Patience—1
# Epoch 13
# Batch 1, Loss: 1.276199, Accuracy: 29.69%
# Batch 2, Loss: 1.242319, Accuracy: 30.47%
# Batch 3, Loss: 1.287521, Accuracy: 31.77%
# Batch 4, Loss: 1.389530, Accuracy: 31.64%
# Batch 5, Loss: 1.310229, Accuracy: 30.00%
# Batch 6, Loss: 1.268235, Accuracy: 29.95%
# Batch 7, Loss: 1.326012, Accuracy: 30.00%
# Training - Epoch 13, Loss: 1.300007, Accuracy: 30.00%
# Validation Batch 1, Loss: 1.194534, Accuracy: 19.61%
# Validation - Epoch 13, Loss: 1.194534, Accuracy: 19.61%
# Patience—2
# Epoch 14
# Batch 1, Loss: 1.232814, Accuracy: 26.56%
# Batch 2, Loss: 1.402802, Accuracy: 28.91%
# Batch 3, Loss: 1.256601, Accuracy: 31.77%
# Batch 4, Loss: 1.367771, Accuracy: 30.47%
# Batch 5, Loss: 1.244095, Accuracy: 33.44%
# Batch 6, Loss: 1.276434, Accuracy: 33.07%
# Batch 7, Loss: 1.233827, Accuracy: 33.17%
# Training - Epoch 14, Loss: 1.287764, Accuracy: 33.17%
# Validation Batch 1, Loss: 1.142574, Accuracy: 52.94%
# Validation - Epoch 14, Loss: 1.142574, Accuracy: 52.94%
# Patience—3
# Epoch 15
# Batch 1, Loss: 1.241433, Accuracy: 39.06%
# Batch 2, Loss: 1.330831, Accuracy: 34.38%
# Batch 3, Loss: 1.300701, Accuracy: 34.38%
# Batch 4, Loss: 1.295352, Accuracy: 34.38%
# Batch 5, Loss: 1.279673, Accuracy: 35.62%
# Batch 6, Loss: 1.329425, Accuracy: 35.42%
# Batch 7, Loss: 1.218638, Accuracy: 35.37%
# Training - Epoch 15, Loss: 1.285151, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.148755, Accuracy: 52.94%
# Validation - Epoch 15, Loss: 1.148755, Accuracy: 52.94%
# Patience—4
# Epoch 16
# Batch 1, Loss: 1.246818, Accuracy: 37.50%
# Batch 2, Loss: 1.272280, Accuracy: 35.16%
# Batch 3, Loss: 1.313535, Accuracy: 34.38%
# Batch 4, Loss: 1.286317, Accuracy: 35.55%
# Batch 5, Loss: 1.283070, Accuracy: 35.00%
# Batch 6, Loss: 1.325440, Accuracy: 32.55%
# Batch 7, Loss: 1.321587, Accuracy: 32.93%
# Training - Epoch 16, Loss: 1.292721, Accuracy: 32.93%
# Validation Batch 1, Loss: 1.164999, Accuracy: 52.94%
# Validation - Epoch 16, Loss: 1.164999, Accuracy: 52.94%
# Patience—5
# Epoch 17
# Batch 1, Loss: 1.275337, Accuracy: 31.25%
# Batch 2, Loss: 1.287057, Accuracy: 39.84%
# Batch 3, Loss: 1.271365, Accuracy: 36.46%
# Batch 4, Loss: 1.248105, Accuracy: 35.94%
# Batch 5, Loss: 1.361234, Accuracy: 37.19%
# Batch 6, Loss: 1.253887, Accuracy: 36.46%
# Batch 7, Loss: 1.374622, Accuracy: 36.10%
# Training - Epoch 17, Loss: 1.295944, Accuracy: 36.10%
# Validation Batch 1, Loss: 1.150675, Accuracy: 52.94%
# Validation - Epoch 17, Loss: 1.150675, Accuracy: 52.94%
# Patience—6
# Epoch 18
# Batch 1, Loss: 1.273390, Accuracy: 40.62%
# Batch 2, Loss: 1.258763, Accuracy: 42.19%
# Batch 3, Loss: 1.297261, Accuracy: 40.10%
# Batch 4, Loss: 1.309964, Accuracy: 38.28%
# Batch 5, Loss: 1.292051, Accuracy: 36.25%
# Batch 6, Loss: 1.317841, Accuracy: 35.16%
# Batch 7, Loss: 1.273064, Accuracy: 35.37%
# Training - Epoch 18, Loss: 1.288905, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.150092, Accuracy: 52.94%
# Validation - Epoch 18, Loss: 1.150092, Accuracy: 52.94%
# Patience—7
# Epoch 19
# Batch 1, Loss: 1.258653, Accuracy: 43.75%
# Batch 2, Loss: 1.361073, Accuracy: 37.50%
# Batch 3, Loss: 1.269099, Accuracy: 38.02%
# Batch 4, Loss: 1.297294, Accuracy: 36.33%
# Batch 5, Loss: 1.260705, Accuracy: 36.56%
# Batch 6, Loss: 1.302380, Accuracy: 35.68%
# Batch 7, Loss: 1.222767, Accuracy: 35.37%
# Training - Epoch 19, Loss: 1.281710, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.169423, Accuracy: 52.94%
# Validation - Epoch 19, Loss: 1.169423, Accuracy: 52.94%
# Patience—8
# Epoch 20
# Batch 1, Loss: 1.286661, Accuracy: 35.94%
# Batch 2, Loss: 1.294817, Accuracy: 36.72%
# Batch 3, Loss: 1.249076, Accuracy: 37.50%
# Batch 4, Loss: 1.184929, Accuracy: 39.45%
# Batch 5, Loss: 1.332858, Accuracy: 37.19%
# Batch 6, Loss: 1.414809, Accuracy: 35.94%
# Batch 7, Loss: 1.224944, Accuracy: 35.85%
# Training - Epoch 20, Loss: 1.284013, Accuracy: 35.85%
# Validation Batch 1, Loss: 1.170385, Accuracy: 19.61%
# Validation - Epoch 20, Loss: 1.170385, Accuracy: 19.61%
# Patience—9
# Epoch 21
# Batch 1, Loss: 1.245601, Accuracy: 32.81%
# Batch 2, Loss: 1.346662, Accuracy: 28.12%
# Batch 3, Loss: 1.238078, Accuracy: 30.21%
# Batch 4, Loss: 1.317096, Accuracy: 32.81%
# Batch 5, Loss: 1.347663, Accuracy: 30.94%
# Batch 6, Loss: 1.297272, Accuracy: 32.81%
# Batch 7, Loss: 1.188291, Accuracy: 34.39%
# Training - Epoch 21, Loss: 1.282952, Accuracy: 34.39%
# Validation Batch 1, Loss: 1.147921, Accuracy: 52.94%
# Validation - Epoch 21, Loss: 1.147921, Accuracy: 52.94%
# Patience—10
# Epoch 22
# Batch 1, Loss: 1.337356, Accuracy: 31.25%
# Batch 2, Loss: 1.195369, Accuracy: 32.81%
# Batch 3, Loss: 1.271123, Accuracy: 33.33%
# Batch 4, Loss: 1.354866, Accuracy: 33.59%
# Batch 5, Loss: 1.276365, Accuracy: 34.06%
# Batch 6, Loss: 1.349389, Accuracy: 34.38%
# Batch 7, Loss: 1.168592, Accuracy: 35.37%
# Training - Epoch 22, Loss: 1.279008, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.129021, Accuracy: 52.94%
# Validation - Epoch 22, Loss: 1.129021, Accuracy: 52.94%
# Patience—11
# Epoch 23
# Batch 1, Loss: 1.233483, Accuracy: 42.19%
# Batch 2, Loss: 1.290034, Accuracy: 42.97%
# Batch 3, Loss: 1.273696, Accuracy: 40.62%
# Batch 4, Loss: 1.359237, Accuracy: 37.11%
# Batch 5, Loss: 1.281915, Accuracy: 37.50%
# Batch 6, Loss: 1.311474, Accuracy: 35.42%
# Batch 7, Loss: 1.338687, Accuracy: 35.37%
# Training - Epoch 23, Loss: 1.298361, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.132630, Accuracy: 52.94%
# Validation - Epoch 23, Loss: 1.132630, Accuracy: 52.94%
# Patience—12
# Epoch 24
# Batch 1, Loss: 1.277066, Accuracy: 42.19%
# Batch 2, Loss: 1.309558, Accuracy: 39.84%
# Batch 3, Loss: 1.307398, Accuracy: 37.50%
# Batch 4, Loss: 1.272812, Accuracy: 35.94%
# Batch 5, Loss: 1.281805, Accuracy: 33.75%
# Batch 6, Loss: 1.301129, Accuracy: 34.64%
# Batch 7, Loss: 1.228656, Accuracy: 35.37%
# Training - Epoch 24, Loss: 1.282632, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.179624, Accuracy: 52.94%
# Validation - Epoch 24, Loss: 1.179624, Accuracy: 52.94%
# Patience—13
# Epoch 25
# Batch 1, Loss: 1.261948, Accuracy: 39.06%
# Batch 2, Loss: 1.254721, Accuracy: 41.41%
# Batch 3, Loss: 1.336666, Accuracy: 41.15%
# Batch 4, Loss: 1.251159, Accuracy: 37.50%
# Batch 5, Loss: 1.291058, Accuracy: 35.00%
# Batch 6, Loss: 1.322940, Accuracy: 35.94%
# Batch 7, Loss: 1.344001, Accuracy: 35.37%
# Training - Epoch 25, Loss: 1.294642, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.155196, Accuracy: 52.94%
# Validation - Epoch 25, Loss: 1.155196, Accuracy: 52.94%
# Patience—14
# Epoch 26
# Batch 1, Loss: 1.364997, Accuracy: 31.25%
# Batch 2, Loss: 1.233203, Accuracy: 33.59%
# Batch 3, Loss: 1.337552, Accuracy: 30.73%
# Batch 4, Loss: 1.252531, Accuracy: 31.25%
# Batch 5, Loss: 1.216187, Accuracy: 32.19%
# Batch 6, Loss: 1.302784, Accuracy: 35.42%
# Batch 7, Loss: 1.336235, Accuracy: 35.37%
# Training - Epoch 26, Loss: 1.291927, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.158951, Accuracy: 52.94%
# Validation - Epoch 26, Loss: 1.158951, Accuracy: 52.94%
# Patience—15
# Epoch 27
# Batch 1, Loss: 1.226991, Accuracy: 50.00%
# Batch 2, Loss: 1.216446, Accuracy: 45.31%
# Batch 3, Loss: 1.270818, Accuracy: 42.71%
# Batch 4, Loss: 1.306589, Accuracy: 39.06%
# Batch 5, Loss: 1.253685, Accuracy: 38.75%
# Batch 6, Loss: 1.532292, Accuracy: 35.16%
# Batch 7, Loss: 1.174091, Accuracy: 35.37%
# Training - Epoch 27, Loss: 1.282987, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.122098, Accuracy: 52.94%
# Validation - Epoch 27, Loss: 1.122098, Accuracy: 52.94%
# Patience—16
# Epoch 28
# Batch 1, Loss: 1.179817, Accuracy: 46.88%
# Batch 2, Loss: 1.334097, Accuracy: 42.19%
# Batch 3, Loss: 1.341193, Accuracy: 35.42%
# Batch 4, Loss: 1.326852, Accuracy: 35.94%
# Batch 5, Loss: 1.224246, Accuracy: 35.62%
# Batch 6, Loss: 1.278896, Accuracy: 35.16%
# Batch 7, Loss: 1.329503, Accuracy: 35.37%
# Training - Epoch 28, Loss: 1.287801, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.160359, Accuracy: 52.94%
# Validation - Epoch 28, Loss: 1.160359, Accuracy: 52.94%
# Patience—17
# Epoch 29
# Batch 1, Loss: 1.186914, Accuracy: 39.06%
# Batch 2, Loss: 1.324253, Accuracy: 34.38%
# Batch 3, Loss: 1.296447, Accuracy: 36.46%
# Batch 4, Loss: 1.285558, Accuracy: 35.16%
# Batch 5, Loss: 1.272331, Accuracy: 35.00%
# Batch 6, Loss: 1.332116, Accuracy: 35.42%
# Batch 7, Loss: 1.271498, Accuracy: 35.37%
# Training - Epoch 29, Loss: 1.281303, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.157622, Accuracy: 52.94%
# Validation - Epoch 29, Loss: 1.157622, Accuracy: 52.94%
# Patience—18
# Epoch 30
# Batch 1, Loss: 1.266441, Accuracy: 45.31%
# Batch 2, Loss: 1.270072, Accuracy: 40.62%
# Batch 3, Loss: 1.270554, Accuracy: 36.98%
# Batch 4, Loss: 1.191972, Accuracy: 37.11%
# Batch 5, Loss: 1.316865, Accuracy: 37.50%
# Batch 6, Loss: 1.356544, Accuracy: 35.68%
# Batch 7, Loss: 1.327019, Accuracy: 35.37%
# Training - Epoch 30, Loss: 1.285638, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.137046, Accuracy: 52.94%
# Validation - Epoch 30, Loss: 1.137046, Accuracy: 52.94%
# Patience—19
# Epoch 31
# Batch 1, Loss: 1.264783, Accuracy: 37.50%
# Batch 2, Loss: 1.329172, Accuracy: 34.38%
# Batch 3, Loss: 1.301280, Accuracy: 32.29%
# Batch 4, Loss: 1.302305, Accuracy: 32.42%
# Batch 5, Loss: 1.297348, Accuracy: 33.44%
# Batch 6, Loss: 1.204170, Accuracy: 34.90%
# Batch 7, Loss: 1.189466, Accuracy: 35.37%
# Training - Epoch 31, Loss: 1.269789, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.160652, Accuracy: 52.94%
# Validation - Epoch 31, Loss: 1.160652, Accuracy: 52.94%
# Patience—20
# Early stopping at epoch 31

# %%
import matplotlib.pyplot as plt

plt.plot(train_accuracy_list, label='Train Accuracy')

# Plotting the second graph
plt.plot(val_accuracy_list, label='Val Accuracy')

# Adding labels and a legend
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Train vs Val Accuracy')
plt.legend()

# Display the plot
plt.show()

plt.plot(train_loss_list, label='Train Loss')

# Plotting the second graph
plt.plot(val_loss_list, label='Val Loss')

# Adding labels and a legend
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train vs Val Loss')
plt.legend()

# Display the plot
plt.show()

# %%
model.eval()

test_loss = 0.0
test_correct = 0
test_total = 0
all_predictions = []
all_labels = []

with torch.no_grad():
    for batch_idx, (images, labels) in enumerate(test_loader):
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)

        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

        print(f"Test Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * test_correct / test_total:.2f}%")

test_loss /= len(test_loader)
test_accuracy = 100 * test_correct / test_total

print(f"Test Set - Loss: {test_loss:.6f}, Accuracy: {test_accuracy:.2f}%")

cm = confusion_matrix(all_labels, all_predictions)
print("Confusion Matrix:")
print(cm)
# Out:
# Test Batch 1, Loss: 1.307353, Accuracy: 32.69%
# Test Set - Loss: 1.307353, Accuracy: 32.69%
# Confusion Matrix:
# [[ 0  0  0  4]
#  [ 0  0  0 15]
#  [ 0  0  0 16]
#  [ 0  0  0 17]]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score

cm = confusion_matrix(all_labels, all_predictions)

# Calculate accuracy
accuracy = accuracy_score(all_labels, all_predictions)

# Calculate percentages for each element
cm_percentage = (cm / np.sum(cm)) * 100

# Plot confusion matrix with count and percentages
fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=['MILD', 'MODERATE', 'NORMAL', 'SEVERE'],
            yticklabels=['MILD', 'MODERATE', 'NORMAL', 'SEVERE'],
            ax=ax)

# Annotate each box with count and percentage
for i in range(len(cm)):
    for j in range(len(cm[0])):
        ax.text(j + 0.5, i + 0.5, f'\n\n{cm_percentage[i, j]:.2f}%',
                ha='center', va='center', color='black')

plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.33

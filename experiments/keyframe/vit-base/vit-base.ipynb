# %%
import timm
import torch
import copy
from torch.utils.data import DataLoader, random_split
from sklearn.metrics import confusion_matrix
from torchvision import transforms, datasets
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def create_vit(model_name):
    if model_name == 'tiny': model = timm.create_model('vit_tiny_patch16_224', pretrained=False, num_classes=4)
    if model_name == 'small': model = timm.create_model('vit_small_patch16_224', pretrained=False, num_classes=4)
    if model_name == 'base': model = timm.create_model('vit_base_patch16_224', pretrained=False, num_classes=4)

    return model

# %%
transform = transforms.Compose([transforms.Resize((224, 224)), transforms.ToTensor(), transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])])

dataset = datasets.ImageFolder(root='/home/ubuntu/Parkinson-Project/keyframes/energy_images', transform=transform)

total_size = len(dataset)
train_size = int(total_size * 0.8) 
validation_size = int(total_size * 0.1) 
test_size = total_size - train_size - validation_size
generator = torch.Generator().manual_seed(0) 
train_dataset, validation_dataset, test_dataset = random_split(dataset, [train_size, validation_size, test_size], generator=generator)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(validation_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
experiment = 'vit-base-130-epochs-early-stopping-keyframes'

# %%
model_type = 'base'
model = create_vit(model_type)

# Model summary to check architecture
print(model)
# Out:
# VisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#     (norm): Identity()
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (patch_drop): Identity()
#   (norm_pre): Identity()
#   (blocks): Sequential(
#     (0): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (4): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (5): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (6): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (7): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (8): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (9): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (10): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (11): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   (fc_norm): Identity()
#   (head_drop): Dropout(p=0.0, inplace=False)
#   (head): Linear(in_features=768, out_features=4, bias=True)
# )

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model.to(device)

num_epochs = 130  
patience = 20  
best_val_loss = float('inf')  
best_model = None  

train_loss_list = list()
val_loss_list = list()
train_accuracy_list = list()
val_accuracy_list = list()

for epoch in range(num_epochs):
    model.train() 
    running_loss = 0.0
    correct = 0
    total = 0
    print(f"Epoch {epoch+1}")

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)  

        optimizer.zero_grad()  
        outputs = model(images)  
        loss = criterion(outputs, labels)  
        loss.backward() 
        optimizer.step() 

        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        print(f"Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * correct / total:.2f}%")

    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct / total
    print(f"Training - Epoch {epoch+1}, Loss: {train_loss:.6f}, Accuracy: {train_accuracy:.2f}%")

    train_loss_list.append(train_loss)
    train_accuracy_list.append(train_accuracy)

    # Validation step
    model.eval()  
    val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():  
        for batch_idx, (images, labels) in enumerate(val_loader):
            images, labels = images.to(device), labels.to(device)  

            outputs = model(images) 
            loss = criterion(outputs, labels) 

            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

            print(f"Validation Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * val_correct / val_total:.2f}%")

    val_loss /= len(val_loader)
    val_accuracy = 100 * val_correct / val_total
    print(f"Validation - Epoch {epoch+1}, Loss: {val_loss:.6f}, Accuracy: {val_accuracy:.2f}%")

    val_loss_list.append(val_loss)
    val_accuracy_list.append(val_accuracy)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = copy.deepcopy(model)
        patience_counter = 0
    else:
        patience_counter += 1

    print(f'Patience—{patience_counter}')

    # Check for early stopping
    if patience_counter >= patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

model = best_model
torch.save(model.state_dict(), f'{experiment}-{model_type}')
# Out:
# Using device: cuda:0
# Epoch 1
# Batch 1, Loss: 1.438610, Accuracy: 29.69%
# Batch 2, Loss: 3.722132, Accuracy: 28.91%
# Batch 3, Loss: 4.423728, Accuracy: 30.73%
# Batch 4, Loss: 2.669658, Accuracy: 31.25%
# Batch 5, Loss: 1.732742, Accuracy: 33.75%
# Batch 6, Loss: 2.005621, Accuracy: 32.29%
# Batch 7, Loss: 2.258720, Accuracy: 31.71%
# Training - Epoch 1, Loss: 2.607316, Accuracy: 31.71%
# Validation Batch 1, Loss: 1.766487, Accuracy: 27.45%
# Validation - Epoch 1, Loss: 1.766487, Accuracy: 27.45%
# Patience—0
# Epoch 2
# Batch 1, Loss: 1.814158, Accuracy: 26.56%
# Batch 2, Loss: 1.441445, Accuracy: 26.56%
# Batch 3, Loss: 1.372519, Accuracy: 29.69%
# Batch 4, Loss: 1.394671, Accuracy: 30.08%
# Batch 5, Loss: 1.566431, Accuracy: 29.69%
# Batch 6, Loss: 1.496374, Accuracy: 31.25%
# Batch 7, Loss: 1.354690, Accuracy: 31.95%
# Training - Epoch 2, Loss: 1.491470, Accuracy: 31.95%
# Validation Batch 1, Loss: 1.317298, Accuracy: 52.94%
# Validation - Epoch 2, Loss: 1.317298, Accuracy: 52.94%
# Patience—0
# Epoch 3
# Batch 1, Loss: 1.576623, Accuracy: 28.12%
# Batch 2, Loss: 1.449562, Accuracy: 31.25%
# Batch 3, Loss: 1.316457, Accuracy: 31.77%
# Batch 4, Loss: 1.295696, Accuracy: 30.08%
# Batch 5, Loss: 1.312697, Accuracy: 30.62%
# Batch 6, Loss: 1.295268, Accuracy: 30.47%
# Batch 7, Loss: 1.324960, Accuracy: 29.51%
# Training - Epoch 3, Loss: 1.367323, Accuracy: 29.51%
# Validation Batch 1, Loss: 1.185315, Accuracy: 27.45%
# Validation - Epoch 3, Loss: 1.185315, Accuracy: 27.45%
# Patience—0
# Epoch 4
# Batch 1, Loss: 1.238119, Accuracy: 25.00%
# Batch 2, Loss: 1.256627, Accuracy: 26.56%
# Batch 3, Loss: 1.345273, Accuracy: 25.00%
# Batch 4, Loss: 1.440612, Accuracy: 24.61%
# Batch 5, Loss: 1.404372, Accuracy: 27.19%
# Batch 6, Loss: 1.325801, Accuracy: 26.56%
# Batch 7, Loss: 1.261256, Accuracy: 27.56%
# Training - Epoch 4, Loss: 1.324580, Accuracy: 27.56%
# Validation Batch 1, Loss: 1.108637, Accuracy: 52.94%
# Validation - Epoch 4, Loss: 1.108637, Accuracy: 52.94%
# Patience—0
# Epoch 5
# Batch 1, Loss: 1.276299, Accuracy: 45.31%
# Batch 2, Loss: 1.348464, Accuracy: 39.06%
# Batch 3, Loss: 1.418016, Accuracy: 35.94%
# Batch 4, Loss: 1.267851, Accuracy: 34.77%
# Batch 5, Loss: 1.230069, Accuracy: 35.94%
# Batch 6, Loss: 1.310613, Accuracy: 35.68%
# Batch 7, Loss: 1.324713, Accuracy: 35.37%
# Training - Epoch 5, Loss: 1.310861, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.203697, Accuracy: 52.94%
# Validation - Epoch 5, Loss: 1.203697, Accuracy: 52.94%
# Patience—1
# Epoch 6
# Batch 1, Loss: 1.350817, Accuracy: 29.69%
# Batch 2, Loss: 1.288829, Accuracy: 35.16%
# Batch 3, Loss: 1.226866, Accuracy: 36.46%
# Batch 4, Loss: 1.281888, Accuracy: 36.33%
# Batch 5, Loss: 1.309578, Accuracy: 36.56%
# Batch 6, Loss: 1.343412, Accuracy: 34.11%
# Batch 7, Loss: 1.339027, Accuracy: 34.15%
# Training - Epoch 6, Loss: 1.305774, Accuracy: 34.15%
# Validation Batch 1, Loss: 1.147353, Accuracy: 52.94%
# Validation - Epoch 6, Loss: 1.147353, Accuracy: 52.94%
# Patience—2
# Epoch 7
# Batch 1, Loss: 1.239348, Accuracy: 39.06%
# Batch 2, Loss: 1.344738, Accuracy: 32.81%
# Batch 3, Loss: 1.311841, Accuracy: 33.85%
# Batch 4, Loss: 1.239543, Accuracy: 34.77%
# Batch 5, Loss: 1.295465, Accuracy: 33.75%
# Batch 6, Loss: 1.364835, Accuracy: 32.81%
# Batch 7, Loss: 1.267618, Accuracy: 31.46%
# Training - Epoch 7, Loss: 1.294770, Accuracy: 31.46%
# Validation Batch 1, Loss: 1.144142, Accuracy: 52.94%
# Validation - Epoch 7, Loss: 1.144142, Accuracy: 52.94%
# Patience—3
# Epoch 8
# Batch 1, Loss: 1.398207, Accuracy: 32.81%
# Batch 2, Loss: 1.311618, Accuracy: 30.47%
# Batch 3, Loss: 1.302628, Accuracy: 31.25%
# Batch 4, Loss: 1.206381, Accuracy: 35.55%
# Batch 5, Loss: 1.316016, Accuracy: 35.00%
# Batch 6, Loss: 1.265585, Accuracy: 34.90%
# Batch 7, Loss: 1.293100, Accuracy: 35.37%
# Training - Epoch 8, Loss: 1.299076, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.136542, Accuracy: 52.94%
# Validation - Epoch 8, Loss: 1.136542, Accuracy: 52.94%
# Patience—4
# Epoch 9
# Batch 1, Loss: 1.258982, Accuracy: 42.19%
# Batch 2, Loss: 1.312971, Accuracy: 37.50%
# Batch 3, Loss: 1.228541, Accuracy: 37.50%
# Batch 4, Loss: 1.310633, Accuracy: 37.50%
# Batch 5, Loss: 1.327823, Accuracy: 36.25%
# Batch 6, Loss: 1.281984, Accuracy: 35.94%
# Batch 7, Loss: 1.319880, Accuracy: 35.37%
# Training - Epoch 9, Loss: 1.291545, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.191952, Accuracy: 19.61%
# Validation - Epoch 9, Loss: 1.191952, Accuracy: 19.61%
# Patience—5
# Epoch 10
# Batch 1, Loss: 1.294681, Accuracy: 34.38%
# Batch 2, Loss: 1.288651, Accuracy: 33.59%
# Batch 3, Loss: 1.253669, Accuracy: 33.85%
# Batch 4, Loss: 1.334892, Accuracy: 30.47%
# Batch 5, Loss: 1.335746, Accuracy: 29.38%
# Batch 6, Loss: 1.259768, Accuracy: 30.47%
# Batch 7, Loss: 1.410532, Accuracy: 30.00%
# Training - Epoch 10, Loss: 1.311134, Accuracy: 30.00%
# Validation Batch 1, Loss: 1.131071, Accuracy: 52.94%
# Validation - Epoch 10, Loss: 1.131071, Accuracy: 52.94%
# Patience—6
# Epoch 11
# Batch 1, Loss: 1.253095, Accuracy: 34.38%
# Batch 2, Loss: 1.235012, Accuracy: 36.72%
# Batch 3, Loss: 1.272899, Accuracy: 37.50%
# Batch 4, Loss: 1.368020, Accuracy: 33.98%
# Batch 5, Loss: 1.321662, Accuracy: 34.06%
# Batch 6, Loss: 1.303612, Accuracy: 35.16%
# Batch 7, Loss: 1.285316, Accuracy: 35.37%
# Training - Epoch 11, Loss: 1.291374, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.172685, Accuracy: 52.94%
# Validation - Epoch 11, Loss: 1.172685, Accuracy: 52.94%
# Patience—7
# Epoch 12
# Batch 1, Loss: 1.358384, Accuracy: 35.94%
# Batch 2, Loss: 1.280095, Accuracy: 36.72%
# Batch 3, Loss: 1.225560, Accuracy: 40.10%
# Batch 4, Loss: 1.306810, Accuracy: 40.62%
# Batch 5, Loss: 1.304105, Accuracy: 37.81%
# Batch 6, Loss: 1.304673, Accuracy: 35.94%
# Batch 7, Loss: 1.357157, Accuracy: 35.37%
# Training - Epoch 12, Loss: 1.305255, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.158668, Accuracy: 52.94%
# Validation - Epoch 12, Loss: 1.158668, Accuracy: 52.94%
# Patience—8
# Epoch 13
# Batch 1, Loss: 1.291273, Accuracy: 28.12%
# Batch 2, Loss: 1.340673, Accuracy: 23.44%
# Batch 3, Loss: 1.322569, Accuracy: 24.48%
# Batch 4, Loss: 1.289914, Accuracy: 27.34%
# Batch 5, Loss: 1.324215, Accuracy: 28.12%
# Batch 6, Loss: 1.276186, Accuracy: 28.65%
# Batch 7, Loss: 1.287185, Accuracy: 28.54%
# Training - Epoch 13, Loss: 1.304574, Accuracy: 28.54%
# Validation Batch 1, Loss: 1.151687, Accuracy: 52.94%
# Validation - Epoch 13, Loss: 1.151687, Accuracy: 52.94%
# Patience—9
# Epoch 14
# Batch 1, Loss: 1.276761, Accuracy: 39.06%
# Batch 2, Loss: 1.241777, Accuracy: 43.75%
# Batch 3, Loss: 1.277292, Accuracy: 43.23%
# Batch 4, Loss: 1.247303, Accuracy: 42.19%
# Batch 5, Loss: 1.472754, Accuracy: 37.50%
# Batch 6, Loss: 1.439457, Accuracy: 35.68%
# Batch 7, Loss: 1.306984, Accuracy: 35.37%
# Training - Epoch 14, Loss: 1.323190, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.157789, Accuracy: 52.94%
# Validation - Epoch 14, Loss: 1.157789, Accuracy: 52.94%
# Patience—10
# Epoch 15
# Batch 1, Loss: 1.257554, Accuracy: 31.25%
# Batch 2, Loss: 1.415062, Accuracy: 28.12%
# Batch 3, Loss: 1.361964, Accuracy: 28.65%
# Batch 4, Loss: 1.332645, Accuracy: 28.91%
# Batch 5, Loss: 1.300059, Accuracy: 29.06%
# Batch 6, Loss: 1.311904, Accuracy: 28.91%
# Batch 7, Loss: 1.258034, Accuracy: 29.51%
# Training - Epoch 15, Loss: 1.319603, Accuracy: 29.51%
# Validation Batch 1, Loss: 1.193446, Accuracy: 27.45%
# Validation - Epoch 15, Loss: 1.193446, Accuracy: 27.45%
# Patience—11
# Epoch 16
# Batch 1, Loss: 1.273943, Accuracy: 32.81%
# Batch 2, Loss: 1.295076, Accuracy: 31.25%
# Batch 3, Loss: 1.319443, Accuracy: 34.90%
# Batch 4, Loss: 1.264599, Accuracy: 35.55%
# Batch 5, Loss: 1.277277, Accuracy: 34.69%
# Batch 6, Loss: 1.343056, Accuracy: 35.68%
# Batch 7, Loss: 1.238227, Accuracy: 36.34%
# Training - Epoch 16, Loss: 1.287374, Accuracy: 36.34%
# Validation Batch 1, Loss: 1.100335, Accuracy: 52.94%
# Validation - Epoch 16, Loss: 1.100335, Accuracy: 52.94%
# Patience—0
# Epoch 17
# Batch 1, Loss: 1.372329, Accuracy: 29.69%
# Batch 2, Loss: 1.182520, Accuracy: 36.72%
# Batch 3, Loss: 1.371262, Accuracy: 32.29%
# Batch 4, Loss: 1.253761, Accuracy: 35.94%
# Batch 5, Loss: 1.316049, Accuracy: 35.00%
# Batch 6, Loss: 1.384482, Accuracy: 34.90%
# Batch 7, Loss: 1.227443, Accuracy: 35.37%
# Training - Epoch 17, Loss: 1.301121, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.160098, Accuracy: 52.94%
# Validation - Epoch 17, Loss: 1.160098, Accuracy: 52.94%
# Patience—1
# Epoch 18
# Batch 1, Loss: 1.348137, Accuracy: 29.69%
# Batch 2, Loss: 1.281427, Accuracy: 36.72%
# Batch 3, Loss: 1.251780, Accuracy: 37.50%
# Batch 4, Loss: 1.309903, Accuracy: 37.50%
# Batch 5, Loss: 1.368503, Accuracy: 35.00%
# Batch 6, Loss: 1.263137, Accuracy: 35.16%
# Batch 7, Loss: 1.235178, Accuracy: 35.37%
# Training - Epoch 18, Loss: 1.294009, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.157561, Accuracy: 52.94%
# Validation - Epoch 18, Loss: 1.157561, Accuracy: 52.94%
# Patience—2
# Epoch 19
# Batch 1, Loss: 1.292341, Accuracy: 39.06%
# Batch 2, Loss: 1.278452, Accuracy: 39.06%
# Batch 3, Loss: 1.278979, Accuracy: 37.50%
# Batch 4, Loss: 1.260156, Accuracy: 35.94%
# Batch 5, Loss: 1.294691, Accuracy: 35.62%
# Batch 6, Loss: 1.359192, Accuracy: 34.64%
# Batch 7, Loss: 1.247545, Accuracy: 35.37%
# Training - Epoch 19, Loss: 1.287337, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.141096, Accuracy: 52.94%
# Validation - Epoch 19, Loss: 1.141096, Accuracy: 52.94%
# Patience—3
# Epoch 20
# Batch 1, Loss: 1.274926, Accuracy: 31.25%
# Batch 2, Loss: 1.288868, Accuracy: 33.59%
# Batch 3, Loss: 1.298217, Accuracy: 34.38%
# Batch 4, Loss: 1.353141, Accuracy: 33.59%
# Batch 5, Loss: 1.282776, Accuracy: 33.75%
# Batch 6, Loss: 1.264044, Accuracy: 33.85%
# Batch 7, Loss: 1.236447, Accuracy: 35.37%
# Training - Epoch 20, Loss: 1.285488, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.157450, Accuracy: 52.94%
# Validation - Epoch 20, Loss: 1.157450, Accuracy: 52.94%
# Patience—4
# Epoch 21
# Batch 1, Loss: 1.278800, Accuracy: 43.75%
# Batch 2, Loss: 1.241561, Accuracy: 44.53%
# Batch 3, Loss: 1.366986, Accuracy: 40.10%
# Batch 4, Loss: 1.348469, Accuracy: 36.33%
# Batch 5, Loss: 1.337968, Accuracy: 34.38%
# Batch 6, Loss: 1.268453, Accuracy: 35.68%
# Batch 7, Loss: 1.377712, Accuracy: 35.37%
# Training - Epoch 21, Loss: 1.317136, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.196656, Accuracy: 19.61%
# Validation - Epoch 21, Loss: 1.196656, Accuracy: 19.61%
# Patience—5
# Epoch 22
# Batch 1, Loss: 1.340325, Accuracy: 25.00%
# Batch 2, Loss: 1.313692, Accuracy: 28.91%
# Batch 3, Loss: 1.310609, Accuracy: 27.60%
# Batch 4, Loss: 1.289423, Accuracy: 27.34%
# Batch 5, Loss: 1.294001, Accuracy: 26.56%
# Batch 6, Loss: 1.290666, Accuracy: 25.52%
# Batch 7, Loss: 1.232416, Accuracy: 25.12%
# Training - Epoch 22, Loss: 1.295876, Accuracy: 25.12%
# Validation Batch 1, Loss: 1.152212, Accuracy: 52.94%
# Validation - Epoch 22, Loss: 1.152212, Accuracy: 52.94%
# Patience—6
# Epoch 23
# Batch 1, Loss: 1.221792, Accuracy: 45.31%
# Batch 2, Loss: 1.289919, Accuracy: 36.72%
# Batch 3, Loss: 1.321213, Accuracy: 35.42%
# Batch 4, Loss: 1.207794, Accuracy: 37.50%
# Batch 5, Loss: 1.430025, Accuracy: 37.81%
# Batch 6, Loss: 1.308912, Accuracy: 38.02%
# Batch 7, Loss: 1.270048, Accuracy: 37.80%
# Training - Epoch 23, Loss: 1.292815, Accuracy: 37.80%
# Validation Batch 1, Loss: 1.128314, Accuracy: 52.94%
# Validation - Epoch 23, Loss: 1.128314, Accuracy: 52.94%
# Patience—7
# Epoch 24
# Batch 1, Loss: 1.230044, Accuracy: 39.06%
# Batch 2, Loss: 1.346018, Accuracy: 35.16%
# Batch 3, Loss: 1.282012, Accuracy: 33.33%
# Batch 4, Loss: 1.287173, Accuracy: 33.98%
# Batch 5, Loss: 1.376431, Accuracy: 32.19%
# Batch 6, Loss: 1.205764, Accuracy: 35.42%
# Batch 7, Loss: 1.278478, Accuracy: 35.37%
# Training - Epoch 24, Loss: 1.286560, Accuracy: 35.37%
# Validation Batch 1, Loss: 1.179168, Accuracy: 52.94%
# Validation - Epoch 24, Loss: 1.179168, Accuracy: 52.94%
# Patience—8
# Epoch 25
# Batch 1, Loss: 1.288314, Accuracy: 35.94%
# Batch 2, Loss: 1.292142, Accuracy: 39.84%
# Batch 3, Loss: 1.226445, Accuracy: 39.06%
# Batch 4, Loss: 1.306264, Accuracy: 37.11%
# Batch 5, Loss: 1.284142, Accuracy: 36.88%
# Batch 6, Loss: 1.305587, Accuracy: 35.42%
# Batch 7, Loss: 1.251569, Accuracy: 36.10%
# Training - Epoch 25, Loss: 1.279209, Accuracy: 36.10%
# Validation Batch 1, Loss: 1.150461, Accuracy: 43.14%
# Validation - Epoch 25, Loss: 1.150461, Accuracy: 43.14%
# Patience—9
# Epoch 26
# Batch 1, Loss: 1.222077, Accuracy: 54.69%
# Batch 2, Loss: 1.272560, Accuracy: 41.41%
# Batch 3, Loss: 1.294531, Accuracy: 38.54%
# Batch 4, Loss: 1.291507, Accuracy: 39.84%
# Batch 5, Loss: 1.280487, Accuracy: 40.94%
# Batch 6, Loss: 1.298648, Accuracy: 39.84%
# Batch 7, Loss: 1.320186, Accuracy: 39.51%
# Training - Epoch 26, Loss: 1.282857, Accuracy: 39.51%
# Validation Batch 1, Loss: 1.138436, Accuracy: 47.06%
# Validation - Epoch 26, Loss: 1.138436, Accuracy: 47.06%
# Patience—10
# Epoch 27
# Batch 1, Loss: 1.225496, Accuracy: 46.88%
# Batch 2, Loss: 1.259273, Accuracy: 46.09%
# Batch 3, Loss: 1.290508, Accuracy: 45.31%
# Batch 4, Loss: 1.204862, Accuracy: 41.41%
# Batch 5, Loss: 1.353436, Accuracy: 39.38%
# Batch 6, Loss: 1.259255, Accuracy: 39.32%
# Batch 7, Loss: 1.267339, Accuracy: 39.02%
# Training - Epoch 27, Loss: 1.265738, Accuracy: 39.02%
# Validation Batch 1, Loss: 1.121814, Accuracy: 52.94%
# Validation - Epoch 27, Loss: 1.121814, Accuracy: 52.94%
# Patience—11
# Epoch 28
# Batch 1, Loss: 1.207292, Accuracy: 35.94%
# Batch 2, Loss: 1.310470, Accuracy: 33.59%
# Batch 3, Loss: 1.248669, Accuracy: 34.38%
# Batch 4, Loss: 1.203157, Accuracy: 38.67%
# Batch 5, Loss: 1.248490, Accuracy: 40.94%
# Batch 6, Loss: 1.229314, Accuracy: 40.89%
# Batch 7, Loss: 1.291793, Accuracy: 40.73%
# Training - Epoch 28, Loss: 1.248455, Accuracy: 40.73%
# Validation Batch 1, Loss: 1.184458, Accuracy: 27.45%
# Validation - Epoch 28, Loss: 1.184458, Accuracy: 27.45%
# Patience—12
# Epoch 29
# Batch 1, Loss: 1.279876, Accuracy: 29.69%
# Batch 2, Loss: 1.279528, Accuracy: 30.47%
# Batch 3, Loss: 1.277240, Accuracy: 31.25%
# Batch 4, Loss: 1.206833, Accuracy: 33.98%
# Batch 5, Loss: 1.276700, Accuracy: 35.31%
# Batch 6, Loss: 1.160476, Accuracy: 36.98%
# Batch 7, Loss: 1.120588, Accuracy: 38.54%
# Training - Epoch 29, Loss: 1.228749, Accuracy: 38.54%
# Validation Batch 1, Loss: 1.085991, Accuracy: 50.98%
# Validation - Epoch 29, Loss: 1.085991, Accuracy: 50.98%
# Patience—0
# Epoch 30
# Batch 1, Loss: 1.257812, Accuracy: 56.25%
# Batch 2, Loss: 1.288945, Accuracy: 50.00%
# Batch 3, Loss: 1.163258, Accuracy: 47.40%
# Batch 4, Loss: 1.076838, Accuracy: 47.66%
# Batch 5, Loss: 1.229545, Accuracy: 45.00%
# Batch 6, Loss: 1.156183, Accuracy: 43.75%
# Batch 7, Loss: 1.122244, Accuracy: 44.15%
# Training - Epoch 30, Loss: 1.184975, Accuracy: 44.15%
# Validation Batch 1, Loss: 1.091011, Accuracy: 43.14%
# Validation - Epoch 30, Loss: 1.091011, Accuracy: 43.14%
# Patience—1
# Epoch 31
# Batch 1, Loss: 1.223772, Accuracy: 42.19%
# Batch 2, Loss: 1.177852, Accuracy: 46.09%
# Batch 3, Loss: 1.274328, Accuracy: 42.71%
# Batch 4, Loss: 1.202730, Accuracy: 42.58%
# Batch 5, Loss: 1.140018, Accuracy: 43.44%
# Batch 6, Loss: 1.168874, Accuracy: 42.97%
# Batch 7, Loss: 1.112922, Accuracy: 43.41%
# Training - Epoch 31, Loss: 1.185785, Accuracy: 43.41%
# Validation Batch 1, Loss: 1.098742, Accuracy: 45.10%
# Validation - Epoch 31, Loss: 1.098742, Accuracy: 45.10%
# Patience—2
# Epoch 32
# Batch 1, Loss: 1.130585, Accuracy: 45.31%
# Batch 2, Loss: 1.077043, Accuracy: 46.09%
# Batch 3, Loss: 1.058764, Accuracy: 47.40%
# Batch 4, Loss: 1.132322, Accuracy: 45.31%
# Batch 5, Loss: 1.121153, Accuracy: 45.94%
# Batch 6, Loss: 1.194685, Accuracy: 46.35%
# Batch 7, Loss: 1.234739, Accuracy: 46.10%
# Training - Epoch 32, Loss: 1.135613, Accuracy: 46.10%
# Validation Batch 1, Loss: 1.178034, Accuracy: 41.18%
# Validation - Epoch 32, Loss: 1.178034, Accuracy: 41.18%
# Patience—3
# Epoch 33
# Batch 1, Loss: 0.969199, Accuracy: 57.81%
# Batch 2, Loss: 0.977326, Accuracy: 61.72%
# Batch 3, Loss: 1.031927, Accuracy: 59.38%
# Batch 4, Loss: 1.049554, Accuracy: 59.77%
# Batch 5, Loss: 1.018674, Accuracy: 59.06%
# Batch 6, Loss: 1.274590, Accuracy: 56.77%
# Batch 7, Loss: 1.113966, Accuracy: 56.83%
# Training - Epoch 33, Loss: 1.062176, Accuracy: 56.83%
# Validation Batch 1, Loss: 1.135020, Accuracy: 45.10%
# Validation - Epoch 33, Loss: 1.135020, Accuracy: 45.10%
# Patience—4
# Epoch 34
# Batch 1, Loss: 0.819251, Accuracy: 73.44%
# Batch 2, Loss: 0.994135, Accuracy: 65.62%
# Batch 3, Loss: 1.079606, Accuracy: 62.50%
# Batch 4, Loss: 0.998669, Accuracy: 61.33%
# Batch 5, Loss: 1.180543, Accuracy: 58.44%
# Batch 6, Loss: 1.108490, Accuracy: 57.03%
# Batch 7, Loss: 0.775539, Accuracy: 58.05%
# Training - Epoch 34, Loss: 0.993748, Accuracy: 58.05%
# Validation Batch 1, Loss: 1.118727, Accuracy: 54.90%
# Validation - Epoch 34, Loss: 1.118727, Accuracy: 54.90%
# Patience—5
# Epoch 35
# Batch 1, Loss: 0.886346, Accuracy: 68.75%
# Batch 2, Loss: 0.912259, Accuracy: 66.41%
# Batch 3, Loss: 0.896654, Accuracy: 64.06%
# Batch 4, Loss: 0.881463, Accuracy: 65.23%
# Batch 5, Loss: 1.094975, Accuracy: 64.38%
# Batch 6, Loss: 1.109161, Accuracy: 62.50%
# Batch 7, Loss: 1.037600, Accuracy: 62.68%
# Training - Epoch 35, Loss: 0.974065, Accuracy: 62.68%
# Validation Batch 1, Loss: 1.133931, Accuracy: 49.02%
# Validation - Epoch 35, Loss: 1.133931, Accuracy: 49.02%
# Patience—6
# Epoch 36
# Batch 1, Loss: 0.863515, Accuracy: 71.88%
# Batch 2, Loss: 0.837267, Accuracy: 68.75%
# Batch 3, Loss: 0.958344, Accuracy: 67.19%
# Batch 4, Loss: 0.902008, Accuracy: 67.97%
# Batch 5, Loss: 0.956904, Accuracy: 65.94%
# Batch 6, Loss: 0.969916, Accuracy: 64.58%
# Batch 7, Loss: 1.012924, Accuracy: 63.90%
# Training - Epoch 36, Loss: 0.928697, Accuracy: 63.90%
# Validation Batch 1, Loss: 1.006433, Accuracy: 60.78%
# Validation - Epoch 36, Loss: 1.006433, Accuracy: 60.78%
# Patience—0
# Epoch 37
# Batch 1, Loss: 1.004368, Accuracy: 54.69%
# Batch 2, Loss: 0.849855, Accuracy: 59.38%
# Batch 3, Loss: 0.752608, Accuracy: 64.58%
# Batch 4, Loss: 0.950849, Accuracy: 64.06%
# Batch 5, Loss: 0.939702, Accuracy: 64.06%
# Batch 6, Loss: 0.917254, Accuracy: 63.80%
# Batch 7, Loss: 0.788936, Accuracy: 63.90%
# Training - Epoch 37, Loss: 0.886225, Accuracy: 63.90%
# Validation Batch 1, Loss: 1.121604, Accuracy: 58.82%
# Validation - Epoch 37, Loss: 1.121604, Accuracy: 58.82%
# Patience—1
# Epoch 38
# Batch 1, Loss: 0.764468, Accuracy: 79.69%
# Batch 2, Loss: 0.938789, Accuracy: 73.44%
# Batch 3, Loss: 0.916003, Accuracy: 68.23%
# Batch 4, Loss: 0.871648, Accuracy: 66.41%
# Batch 5, Loss: 0.685690, Accuracy: 68.12%
# Batch 6, Loss: 0.941097, Accuracy: 67.19%
# Batch 7, Loss: 0.716558, Accuracy: 67.07%
# Training - Epoch 38, Loss: 0.833465, Accuracy: 67.07%
# Validation Batch 1, Loss: 1.080903, Accuracy: 56.86%
# Validation - Epoch 38, Loss: 1.080903, Accuracy: 56.86%
# Patience—2
# Epoch 39
# Batch 1, Loss: 0.743609, Accuracy: 70.31%
# Batch 2, Loss: 0.610972, Accuracy: 75.00%
# Batch 3, Loss: 0.731087, Accuracy: 71.35%
# Batch 4, Loss: 0.810628, Accuracy: 72.27%
# Batch 5, Loss: 0.855811, Accuracy: 71.56%
# Batch 6, Loss: 0.693686, Accuracy: 72.66%
# Batch 7, Loss: 1.157976, Accuracy: 71.71%
# Training - Epoch 39, Loss: 0.800538, Accuracy: 71.71%
# Validation Batch 1, Loss: 1.247524, Accuracy: 52.94%
# Validation - Epoch 39, Loss: 1.247524, Accuracy: 52.94%
# Patience—3
# Epoch 40
# Batch 1, Loss: 0.615674, Accuracy: 78.12%
# Batch 2, Loss: 0.715089, Accuracy: 74.22%
# Batch 3, Loss: 0.733620, Accuracy: 72.92%
# Batch 4, Loss: 0.840103, Accuracy: 71.48%
# Batch 5, Loss: 0.561528, Accuracy: 71.25%
# Batch 6, Loss: 0.928887, Accuracy: 68.49%
# Batch 7, Loss: 0.710519, Accuracy: 69.02%
# Training - Epoch 40, Loss: 0.729346, Accuracy: 69.02%
# Validation Batch 1, Loss: 1.285481, Accuracy: 52.94%
# Validation - Epoch 40, Loss: 1.285481, Accuracy: 52.94%
# Patience—4
# Epoch 41
# Batch 1, Loss: 0.640909, Accuracy: 76.56%
# Batch 2, Loss: 0.632974, Accuracy: 76.56%
# Batch 3, Loss: 0.643523, Accuracy: 74.48%
# Batch 4, Loss: 0.586323, Accuracy: 75.78%
# Batch 5, Loss: 0.742572, Accuracy: 75.62%
# Batch 6, Loss: 0.682699, Accuracy: 74.74%
# Batch 7, Loss: 1.160510, Accuracy: 73.17%
# Training - Epoch 41, Loss: 0.727073, Accuracy: 73.17%
# Validation Batch 1, Loss: 1.109700, Accuracy: 62.75%
# Validation - Epoch 41, Loss: 1.109700, Accuracy: 62.75%
# Patience—5
# Epoch 42
# Batch 1, Loss: 0.614678, Accuracy: 76.56%
# Batch 2, Loss: 0.724446, Accuracy: 74.22%
# Batch 3, Loss: 0.511252, Accuracy: 77.08%
# Batch 4, Loss: 0.685388, Accuracy: 75.39%
# Batch 5, Loss: 0.780536, Accuracy: 74.38%
# Batch 6, Loss: 0.609876, Accuracy: 74.22%
# Batch 7, Loss: 0.558351, Accuracy: 74.63%
# Training - Epoch 42, Loss: 0.640647, Accuracy: 74.63%
# Validation Batch 1, Loss: 1.208330, Accuracy: 54.90%
# Validation - Epoch 42, Loss: 1.208330, Accuracy: 54.90%
# Patience—6
# Epoch 43
# Batch 1, Loss: 0.519671, Accuracy: 79.69%
# Batch 2, Loss: 0.458568, Accuracy: 80.47%
# Batch 3, Loss: 0.657266, Accuracy: 79.17%
# Batch 4, Loss: 0.745770, Accuracy: 78.12%
# Batch 5, Loss: 0.540994, Accuracy: 77.81%
# Batch 6, Loss: 0.629701, Accuracy: 77.34%
# Batch 7, Loss: 0.682044, Accuracy: 76.10%
# Training - Epoch 43, Loss: 0.604859, Accuracy: 76.10%
# Validation Batch 1, Loss: 1.622467, Accuracy: 52.94%
# Validation - Epoch 43, Loss: 1.622467, Accuracy: 52.94%
# Patience—7
# Epoch 44
# Batch 1, Loss: 0.706671, Accuracy: 71.88%
# Batch 2, Loss: 0.781393, Accuracy: 69.53%
# Batch 3, Loss: 0.579387, Accuracy: 71.88%
# Batch 4, Loss: 0.465973, Accuracy: 76.17%
# Batch 5, Loss: 0.576563, Accuracy: 77.19%
# Batch 6, Loss: 0.709540, Accuracy: 77.08%
# Batch 7, Loss: 0.926355, Accuracy: 76.10%
# Training - Epoch 44, Loss: 0.677983, Accuracy: 76.10%
# Validation Batch 1, Loss: 0.985507, Accuracy: 60.78%
# Validation - Epoch 44, Loss: 0.985507, Accuracy: 60.78%
# Patience—0
# Epoch 45
# Batch 1, Loss: 0.466533, Accuracy: 85.94%
# Batch 2, Loss: 0.439035, Accuracy: 86.72%
# Batch 3, Loss: 0.624440, Accuracy: 82.81%
# Batch 4, Loss: 0.649081, Accuracy: 80.47%
# Batch 5, Loss: 0.579833, Accuracy: 79.69%
# Batch 6, Loss: 0.372075, Accuracy: 81.25%
# Batch 7, Loss: 0.599185, Accuracy: 81.22%
# Training - Epoch 45, Loss: 0.532883, Accuracy: 81.22%
# Validation Batch 1, Loss: 1.227239, Accuracy: 54.90%
# Validation - Epoch 45, Loss: 1.227239, Accuracy: 54.90%
# Patience—1
# Epoch 46
# Batch 1, Loss: 0.564765, Accuracy: 75.00%
# Batch 2, Loss: 0.477156, Accuracy: 78.12%
# Batch 3, Loss: 0.512753, Accuracy: 77.08%
# Batch 4, Loss: 0.546350, Accuracy: 76.95%
# Batch 5, Loss: 0.353881, Accuracy: 80.31%
# Batch 6, Loss: 0.418986, Accuracy: 80.47%
# Batch 7, Loss: 0.534250, Accuracy: 80.73%
# Training - Epoch 46, Loss: 0.486878, Accuracy: 80.73%
# Validation Batch 1, Loss: 1.314616, Accuracy: 49.02%
# Validation - Epoch 46, Loss: 1.314616, Accuracy: 49.02%
# Patience—2
# Epoch 47
# Batch 1, Loss: 0.446948, Accuracy: 79.69%
# Batch 2, Loss: 0.267546, Accuracy: 85.94%
# Batch 3, Loss: 0.507040, Accuracy: 84.38%
# Batch 4, Loss: 0.459842, Accuracy: 83.98%
# Batch 5, Loss: 0.644994, Accuracy: 81.56%
# Batch 6, Loss: 0.586772, Accuracy: 80.47%
# Batch 7, Loss: 0.489756, Accuracy: 80.49%
# Training - Epoch 47, Loss: 0.486128, Accuracy: 80.49%
# Validation Batch 1, Loss: 1.293266, Accuracy: 56.86%
# Validation - Epoch 47, Loss: 1.293266, Accuracy: 56.86%
# Patience—3
# Epoch 48
# Batch 1, Loss: 0.516860, Accuracy: 76.56%
# Batch 2, Loss: 0.334187, Accuracy: 81.25%
# Batch 3, Loss: 0.326101, Accuracy: 83.33%
# Batch 4, Loss: 0.399460, Accuracy: 83.20%
# Batch 5, Loss: 0.441508, Accuracy: 82.81%
# Batch 6, Loss: 0.492880, Accuracy: 82.55%
# Batch 7, Loss: 0.253282, Accuracy: 83.41%
# Training - Epoch 48, Loss: 0.394897, Accuracy: 83.41%
# Validation Batch 1, Loss: 1.269601, Accuracy: 56.86%
# Validation - Epoch 48, Loss: 1.269601, Accuracy: 56.86%
# Patience—4
# Epoch 49
# Batch 1, Loss: 0.354076, Accuracy: 89.06%
# Batch 2, Loss: 0.319853, Accuracy: 87.50%
# Batch 3, Loss: 0.336687, Accuracy: 86.46%
# Batch 4, Loss: 0.392708, Accuracy: 86.72%
# Batch 5, Loss: 0.263900, Accuracy: 87.50%
# Batch 6, Loss: 0.503739, Accuracy: 85.68%
# Batch 7, Loss: 0.363332, Accuracy: 85.12%
# Training - Epoch 49, Loss: 0.362042, Accuracy: 85.12%
# Validation Batch 1, Loss: 1.347775, Accuracy: 58.82%
# Validation - Epoch 49, Loss: 1.347775, Accuracy: 58.82%
# Patience—5
# Epoch 50
# Batch 1, Loss: 0.353874, Accuracy: 89.06%
# Batch 2, Loss: 0.325412, Accuracy: 88.28%
# Batch 3, Loss: 0.252676, Accuracy: 89.58%
# Batch 4, Loss: 0.133545, Accuracy: 91.02%
# Batch 5, Loss: 0.436096, Accuracy: 89.06%
# Batch 6, Loss: 0.303155, Accuracy: 88.80%
# Batch 7, Loss: 0.275070, Accuracy: 88.78%
# Training - Epoch 50, Loss: 0.297118, Accuracy: 88.78%
# Validation Batch 1, Loss: 1.719875, Accuracy: 60.78%
# Validation - Epoch 50, Loss: 1.719875, Accuracy: 60.78%
# Patience—6
# Epoch 51
# Batch 1, Loss: 0.246119, Accuracy: 92.19%
# Batch 2, Loss: 0.240121, Accuracy: 90.62%
# Batch 3, Loss: 0.179875, Accuracy: 91.67%
# Batch 4, Loss: 0.274568, Accuracy: 91.80%
# Batch 5, Loss: 0.384460, Accuracy: 91.56%
# Batch 6, Loss: 0.344571, Accuracy: 89.84%
# Batch 7, Loss: 0.275100, Accuracy: 89.51%
# Training - Epoch 51, Loss: 0.277831, Accuracy: 89.51%
# Validation Batch 1, Loss: 1.485834, Accuracy: 60.78%
# Validation - Epoch 51, Loss: 1.485834, Accuracy: 60.78%
# Patience—7
# Epoch 52
# Batch 1, Loss: 0.266630, Accuracy: 89.06%
# Batch 2, Loss: 0.255674, Accuracy: 91.41%
# Batch 3, Loss: 0.298941, Accuracy: 91.15%
# Batch 4, Loss: 0.281955, Accuracy: 89.84%
# Batch 5, Loss: 0.332572, Accuracy: 88.44%
# Batch 6, Loss: 0.251530, Accuracy: 89.06%
# Batch 7, Loss: 0.255752, Accuracy: 89.51%
# Training - Epoch 52, Loss: 0.277579, Accuracy: 89.51%
# Validation Batch 1, Loss: 1.588905, Accuracy: 54.90%
# Validation - Epoch 52, Loss: 1.588905, Accuracy: 54.90%
# Patience—8
# Epoch 53
# Batch 1, Loss: 0.356218, Accuracy: 81.25%
# Batch 2, Loss: 0.184907, Accuracy: 88.28%
# Batch 3, Loss: 0.242944, Accuracy: 90.10%
# Batch 4, Loss: 0.385012, Accuracy: 88.28%
# Batch 5, Loss: 0.353509, Accuracy: 87.81%
# Batch 6, Loss: 0.030227, Accuracy: 89.84%
# Batch 7, Loss: 0.211128, Accuracy: 90.00%
# Training - Epoch 53, Loss: 0.251992, Accuracy: 90.00%
# Validation Batch 1, Loss: 1.687675, Accuracy: 54.90%
# Validation - Epoch 53, Loss: 1.687675, Accuracy: 54.90%
# Patience—9
# Epoch 54
# Batch 1, Loss: 0.171057, Accuracy: 93.75%
# Batch 2, Loss: 0.113790, Accuracy: 94.53%
# Batch 3, Loss: 0.212752, Accuracy: 92.19%
# Batch 4, Loss: 0.226651, Accuracy: 91.80%
# Batch 5, Loss: 0.350465, Accuracy: 90.62%
# Batch 6, Loss: 0.255372, Accuracy: 90.89%
# Batch 7, Loss: 0.152594, Accuracy: 90.98%
# Training - Epoch 54, Loss: 0.211812, Accuracy: 90.98%
# Validation Batch 1, Loss: 2.266431, Accuracy: 52.94%
# Validation - Epoch 54, Loss: 2.266431, Accuracy: 52.94%
# Patience—10
# Epoch 55
# Batch 1, Loss: 0.256084, Accuracy: 89.06%
# Batch 2, Loss: 0.287831, Accuracy: 92.19%
# Batch 3, Loss: 0.261228, Accuracy: 90.62%
# Batch 4, Loss: 0.353394, Accuracy: 89.84%
# Batch 5, Loss: 0.462496, Accuracy: 89.38%
# Batch 6, Loss: 0.351106, Accuracy: 88.80%
# Batch 7, Loss: 0.058572, Accuracy: 89.51%
# Training - Epoch 55, Loss: 0.290102, Accuracy: 89.51%
# Validation Batch 1, Loss: 1.837385, Accuracy: 58.82%
# Validation - Epoch 55, Loss: 1.837385, Accuracy: 58.82%
# Patience—11
# Epoch 56
# Batch 1, Loss: 0.313826, Accuracy: 85.94%
# Batch 2, Loss: 0.117985, Accuracy: 91.41%
# Batch 3, Loss: 0.513429, Accuracy: 87.50%
# Batch 4, Loss: 0.283601, Accuracy: 88.67%
# Batch 5, Loss: 0.116327, Accuracy: 90.31%
# Batch 6, Loss: 0.166927, Accuracy: 91.15%
# Batch 7, Loss: 0.263317, Accuracy: 90.98%
# Training - Epoch 56, Loss: 0.253630, Accuracy: 90.98%
# Validation Batch 1, Loss: 1.255796, Accuracy: 58.82%
# Validation - Epoch 56, Loss: 1.255796, Accuracy: 58.82%
# Patience—12
# Epoch 57
# Batch 1, Loss: 0.239736, Accuracy: 90.62%
# Batch 2, Loss: 0.161276, Accuracy: 92.19%
# Batch 3, Loss: 0.134478, Accuracy: 93.23%
# Batch 4, Loss: 0.149735, Accuracy: 93.36%
# Batch 5, Loss: 0.299379, Accuracy: 93.44%
# Batch 6, Loss: 0.346608, Accuracy: 92.71%
# Batch 7, Loss: 0.193031, Accuracy: 92.93%
# Training - Epoch 57, Loss: 0.217749, Accuracy: 92.93%
# Validation Batch 1, Loss: 2.152589, Accuracy: 49.02%
# Validation - Epoch 57, Loss: 2.152589, Accuracy: 49.02%
# Patience—13
# Epoch 58
# Batch 1, Loss: 0.188987, Accuracy: 93.75%
# Batch 2, Loss: 0.175461, Accuracy: 92.97%
# Batch 3, Loss: 0.236714, Accuracy: 92.71%
# Batch 4, Loss: 0.037484, Accuracy: 94.53%
# Batch 5, Loss: 0.121151, Accuracy: 94.69%
# Batch 6, Loss: 0.440234, Accuracy: 93.23%
# Batch 7, Loss: 0.415789, Accuracy: 92.68%
# Training - Epoch 58, Loss: 0.230831, Accuracy: 92.68%
# Validation Batch 1, Loss: 1.862741, Accuracy: 54.90%
# Validation - Epoch 58, Loss: 1.862741, Accuracy: 54.90%
# Patience—14
# Epoch 59
# Batch 1, Loss: 0.087128, Accuracy: 95.31%
# Batch 2, Loss: 0.430215, Accuracy: 88.28%
# Batch 3, Loss: 0.377966, Accuracy: 86.98%
# Batch 4, Loss: 0.083332, Accuracy: 89.84%
# Batch 5, Loss: 0.155708, Accuracy: 90.94%
# Batch 6, Loss: 0.476426, Accuracy: 89.84%
# Batch 7, Loss: 0.240888, Accuracy: 90.00%
# Training - Epoch 59, Loss: 0.264523, Accuracy: 90.00%
# Validation Batch 1, Loss: 1.936590, Accuracy: 54.90%
# Validation - Epoch 59, Loss: 1.936590, Accuracy: 54.90%
# Patience—15
# Epoch 60
# Batch 1, Loss: 0.206916, Accuracy: 93.75%
# Batch 2, Loss: 0.087286, Accuracy: 96.09%
# Batch 3, Loss: 0.184084, Accuracy: 93.75%
# Batch 4, Loss: 0.177207, Accuracy: 93.75%
# Batch 5, Loss: 0.162937, Accuracy: 94.06%
# Batch 6, Loss: 0.134257, Accuracy: 94.53%
# Batch 7, Loss: 0.281264, Accuracy: 94.15%
# Training - Epoch 60, Loss: 0.176279, Accuracy: 94.15%
# Validation Batch 1, Loss: 1.753534, Accuracy: 58.82%
# Validation - Epoch 60, Loss: 1.753534, Accuracy: 58.82%
# Patience—16
# Epoch 61
# Batch 1, Loss: 0.105660, Accuracy: 96.88%
# Batch 2, Loss: 0.131792, Accuracy: 96.09%
# Batch 3, Loss: 0.189283, Accuracy: 95.31%
# Batch 4, Loss: 0.168978, Accuracy: 94.92%
# Batch 5, Loss: 0.090122, Accuracy: 95.31%
# Batch 6, Loss: 0.159114, Accuracy: 95.05%
# Batch 7, Loss: 0.020012, Accuracy: 95.37%
# Training - Epoch 61, Loss: 0.123566, Accuracy: 95.37%
# Validation Batch 1, Loss: 1.499991, Accuracy: 62.75%
# Validation - Epoch 61, Loss: 1.499991, Accuracy: 62.75%
# Patience—17
# Epoch 62
# Batch 1, Loss: 0.133512, Accuracy: 95.31%
# Batch 2, Loss: 0.094776, Accuracy: 96.09%
# Batch 3, Loss: 0.047256, Accuracy: 96.88%
# Batch 4, Loss: 0.096830, Accuracy: 96.88%
# Batch 5, Loss: 0.080596, Accuracy: 96.88%
# Batch 6, Loss: 0.031901, Accuracy: 97.40%
# Batch 7, Loss: 0.147340, Accuracy: 96.83%
# Training - Epoch 62, Loss: 0.090316, Accuracy: 96.83%
# Validation Batch 1, Loss: 2.178021, Accuracy: 62.75%
# Validation - Epoch 62, Loss: 2.178021, Accuracy: 62.75%
# Patience—18
# Epoch 63
# Batch 1, Loss: 0.094533, Accuracy: 96.88%
# Batch 2, Loss: 0.096974, Accuracy: 96.09%
# Batch 3, Loss: 0.099783, Accuracy: 95.83%
# Batch 4, Loss: 0.071281, Accuracy: 96.48%
# Batch 5, Loss: 0.023682, Accuracy: 97.19%
# Batch 6, Loss: 0.059673, Accuracy: 97.40%
# Batch 7, Loss: 0.174100, Accuracy: 97.32%
# Training - Epoch 63, Loss: 0.088575, Accuracy: 97.32%
# Validation Batch 1, Loss: 2.456898, Accuracy: 62.75%
# Validation - Epoch 63, Loss: 2.456898, Accuracy: 62.75%
# Patience—19
# Epoch 64
# Batch 1, Loss: 0.013215, Accuracy: 100.00%
# Batch 2, Loss: 0.018412, Accuracy: 100.00%
# Batch 3, Loss: 0.274707, Accuracy: 95.83%
# Batch 4, Loss: 0.110393, Accuracy: 95.70%
# Batch 5, Loss: 0.454051, Accuracy: 94.69%
# Batch 6, Loss: 0.265833, Accuracy: 94.27%
# Batch 7, Loss: 0.498794, Accuracy: 93.41%
# Training - Epoch 64, Loss: 0.233629, Accuracy: 93.41%
# Validation Batch 1, Loss: 1.796915, Accuracy: 64.71%
# Validation - Epoch 64, Loss: 1.796915, Accuracy: 64.71%
# Patience—20
# Early stopping at epoch 64

# %%
import matplotlib.pyplot as plt

plt.plot(train_accuracy_list, label='Train Accuracy')

# Plotting the second graph
plt.plot(val_accuracy_list, label='Val Accuracy')

# Adding labels and a legend
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Train vs Val Accuracy')
plt.legend()

# Display the plot
plt.show()

plt.plot(train_loss_list, label='Train Loss')

# Plotting the second graph
plt.plot(val_loss_list, label='Val Loss')

# Adding labels and a legend
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train vs Val Loss')
plt.legend()

# Display the plot
plt.show()

# %%
model.eval()

test_loss = 0.0
test_correct = 0
test_total = 0
all_predictions = []
all_labels = []

with torch.no_grad():
    for batch_idx, (images, labels) in enumerate(test_loader):
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)

        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

        print(f"Test Batch {batch_idx+1}, Loss: {loss.item():.6f}, Accuracy: {100 * test_correct / test_total:.2f}%")

test_loss /= len(test_loader)
test_accuracy = 100 * test_correct / test_total

print(f"Test Set - Loss: {test_loss:.6f}, Accuracy: {test_accuracy:.2f}%")

cm = confusion_matrix(all_labels, all_predictions)
print("Confusion Matrix:")
print(cm)
# Out:
# Test Batch 1, Loss: 1.322434, Accuracy: 59.62%
# Test Set - Loss: 1.322434, Accuracy: 59.62%
# Confusion Matrix:
# [[ 2  0  1  1]
#  [ 0  5  4  6]
#  [ 0  3 12  1]
#  [ 0  3  2 12]]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score

cm = confusion_matrix(all_labels, all_predictions)

# Calculate accuracy
accuracy = accuracy_score(all_labels, all_predictions)

# Calculate percentages for each element
cm_percentage = (cm / np.sum(cm)) * 100

# Plot confusion matrix with count and percentages
fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=['MILD', 'MODERATE', 'NORMAL', 'SEVERE'],
            yticklabels=['MILD', 'MODERATE', 'NORMAL', 'SEVERE'],
            ax=ax)

# Annotate each box with count and percentage
for i in range(len(cm)):
    for j in range(len(cm[0])):
        ax.text(j + 0.5, i + 0.5, f'\n\n{cm_percentage[i, j]:.2f}%',
                ha='center', va='center', color='black')

plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.60
